# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/HDA/Novel_BinaryML.csv')

# %%
import numpy as np

# %% [markdown]
# # Word2Vec

# %% [markdown]
# **Bi-gram**

# %%
import pandas as pd
from gensim.models import Word2Vec

# Define a function to generate 2-grams from a protein sequence
def generate_ngrams(sequence):
    n = 2  # Length of the n-grams
    return [sequence[i:i+n] for i in range(len(sequence) - n + 1)]

# Apply the function to create a new column '2grams' in your DataFrame
df['2grams'] = df['Sequence'].apply(generate_ngrams)

# Train a Word2Vec model on the 2-grams
bigrams = list(df['2grams'])
model = Word2Vec(bigrams, vector_size=20, window=7, min_count=1, sg=0, epochs=30)  # Adjust parameters as needed

# Extract embeddings for each token in the 2-grams
def get_embedding(token):
    try:
        return model.wv[token].tolist()
    except KeyError:
        # Handle the case where the token is not in the vocabulary
        return [0.0] * 100  # Return a vector of zeros of the same dimension as your model

# Create a new column 'embeddings' containing embeddings for each 2-gram
df['2gramembeddings'] = df['2grams'].apply(lambda tokens: [get_embedding(token) for token in tokens])

# Print the DataFrame with 2-grams and embeddings
print(df[['2grams', '2gramembeddings']])
# Out:
#                                                 2grams  \
# 0    [MD, DL, LC, CS, SS, ST, TG, GR, RG, GA, AC, C...
# 1    [MD, DT, TV, VL, LM, MA, AT, TT, TP, PP, PI, I...
# 2    [MS, SS, SS, SS, SL, LV, VT, TS, SL, LL, LF, F...
# 3    [MA, AC, CR, RF, FP, PL, LH, HS, SS, SS, SP, P...
# 4    [MQ, QS, SA, AM, MA, AL, LS, SF, FS, SQ, QT, T...
# ..                                                 ...
# 116  [MA, AV, VL, LS, ST, TI, IY, YS, SI, IT, TR, R...
# 117  [MM, MS, SI, IP, PM, ME, EL, LM, MS, SI, IR, R...
# 118  [MG, GF, FL, LV, VA, AV, VM, MN, NF, FS, SP, P...
# 119  [MA, AY, YS, SL, LP, PT, TF, FP, PQ, QA, AL, L...
# 120  [MA, AA, AS, SL, LQ, QS, SA, AN, NP, PT, TL, L...
#
#                                        2gramembeddings
# 0    [[0.5513969659805298, 0.816918134689331, 2.646...
# 1    [[0.5513969659805298, 0.816918134689331, 2.646...
# 2    [[-0.3761202394962311, 2.6349804401397705, -1....
# 3    [[0.9010903835296631, 4.066753387451172, -1.08...
# 4    [[-0.2562788426876068, 0.25300154089927673, 2....
# ..                                                 ...
# 116  [[0.9010903835296631, 4.066753387451172, -1.08...
# 117  [[0.34365248680114746, 1.6378687620162964, 0.1...
# 118  [[-0.247440904378891, -0.19944444298744202, 0....
# 119  [[0.9010903835296631, 4.066753387451172, -1.08...
# 120  [[0.9010903835296631, 4.066753387451172, -1.08...
#
# [121 rows x 2 columns]

# %% [markdown]
# **Tri-gram**

# %%
import pandas as pd
from gensim.models import Word2Vec

# Define a function to generate 3-grams from a protein sequence
def generate_ngrams(sequence):
    n = 3  # Length of the n-grams
    return [sequence[i:i+n] for i in range(len(sequence) - n + 1)]

# Apply the function to create a new column '3grams' in your DataFrame
df['3grams'] = df['Sequence'].apply(generate_ngrams)

# Train a Word2Vec model on the 3-grams
trigrams = list(df['3grams'])
model = Word2Vec(trigrams, vector_size=20, window=7, min_count=1, sg=0, epochs=30)  # Adjust parameters as needed

# Extract embeddings for each token in the 3-grams
def get_embedding(token):
    try:
        return model.wv[token].tolist()
    except KeyError:
        # Handle the case where the token is not in the vocabulary
        return [0.0] * 100  # Return a vector of zeros of the same dimension as your model

# Create a new column 'embeddings' containing embeddings for each 3-gram
df['3gramembeddings'] = df['3grams'].apply(lambda tokens: [get_embedding(token) for token in tokens])

# Print the DataFrame with 3-grams and embeddings
print(df[['3grams', '3gramembeddings']])
# Out:
#                                                 3grams  \
# 0    [MDL, DLC, LCS, CSS, SST, STG, TGR, GRG, RGA, ...
# 1    [MDT, DTV, TVL, VLM, LMA, MAT, ATT, TTP, TPP, ...
# 2    [MSS, SSS, SSS, SSL, SLV, LVT, VTS, TSL, SLL, ...
# 3    [MAC, ACR, CRF, RFP, FPL, PLH, LHS, HSS, SSS, ...
# 4    [MQS, QSA, SAM, AMA, MAL, ALS, LSF, SFS, FSQ, ...
# ..                                                 ...
# 116  [MAV, AVL, VLS, LST, STI, TIY, IYS, YSI, SIT, ...
# 117  [MMS, MSI, SIP, IPM, PME, MEL, ELM, LMS, MSI, ...
# 118  [MGF, GFL, FLV, LVA, VAV, AVM, VMN, MNF, NFS, ...
# 119  [MAY, AYS, YSL, SLP, LPT, PTF, TFP, FPQ, PQA, ...
# 120  [MAA, AAS, ASL, SLQ, LQS, QSA, SAN, ANP, NPT, ...
#
#                                        3gramembeddings
# 0    [[-0.2074774205684662, 0.17316001653671265, -0...
# 1    [[-0.0768902599811554, 0.08130736649036407, -0...
# 2    [[-0.4136641025543213, 0.17836186289787292, 0....
# 3    [[-0.037084948271512985, 0.0972246304154396, -...
# 4    [[-0.07017701119184494, 0.16342201828956604, 0...
# ..                                                 ...
# 116  [[0.26212114095687866, 0.39341050386428833, 0....
# 117  [[-0.02964147739112377, 0.23572146892547607, -...
# 118  [[0.04396333172917366, 0.07781205326318741, 0....
# 119  [[-0.1768399178981781, 0.41961678862571716, -0...
# 120  [[0.6701198816299438, 0.7450931072235107, 0.86...
#
# [121 rows x 2 columns]

# %% [markdown]
# **4-gram**

# %%
import pandas as pd
from gensim.models import Word2Vec

# Define a function to generate 4-grams from a protein sequence
def generate_ngrams(sequence):
    n = 4  # Length of the n-grams
    return [sequence[i:i+n] for i in range(len(sequence) - n + 1)]

# Apply the function to create a new column '4grams' in your DataFrame
df['4grams'] = df['Sequence'].apply(generate_ngrams)

# Train a Word2Vec model on the 4-grams
fourgrams = list(df['4grams'])
model = Word2Vec(fourgrams, vector_size=20, window=7, min_count=1, sg=0, epochs=30)  # Adjust parameters as needed

# Extract embeddings for each token in the 4-grams
def get_embedding(token):
    try:
        return model.wv[token].tolist()
    except KeyError:
        # Handle the case where the token is not in the vocabulary
        return [0.0] * 100  # Return a vector of zeros of the same dimension as your model

# Create a new column 'embeddings' containing embeddings for each 4-gram
df['4gramembeddings'] = df['4grams'].apply(lambda tokens: [get_embedding(token) for token in tokens])

# Print the DataFrame with 4-grams and embeddings
print(df[['4grams', '4gramembeddings']])
# Out:
#                                                 4grams  \
# 0    [MDLC, DLCS, LCSS, CSST, SSTG, STGR, TGRG, GRG...
# 1    [MDTV, DTVL, TVLM, VLMA, LMAT, MATT, ATTP, TTP...
# 2    [MSSS, SSSS, SSSL, SSLV, SLVT, LVTS, VTSL, TSL...
# 3    [MACR, ACRF, CRFP, RFPL, FPLH, PLHS, LHSS, HSS...
# 4    [MQSA, QSAM, SAMA, AMAL, MALS, ALSF, LSFS, SFS...
# ..                                                 ...
# 116  [MAVL, AVLS, VLST, LSTI, STIY, TIYS, IYSI, YSI...
# 117  [MMSI, MSIP, SIPM, IPME, PMEL, MELM, ELMS, LMS...
# 118  [MGFL, GFLV, FLVA, LVAV, VAVM, AVMN, VMNF, MNF...
# 119  [MAYS, AYSL, YSLP, SLPT, LPTF, PTFP, TFPQ, FPQ...
# 120  [MAAS, AASL, ASLQ, SLQS, LQSA, QSAN, SANP, ANP...
#
#                                        4gramembeddings
# 0    [[0.0267899539321661, -0.0377693772315979, 0.0...
# 1    [[-0.0052870879881083965, 0.04972095414996147,...
# 2    [[-0.03778698295354843, -0.003111106576398015,...
# 3    [[0.004118323791772127, 0.01852506771683693, 0...
# 4    [[0.009896600618958473, -0.022809717804193497,...
# ..                                                 ...
# 116  [[-0.013760511763393879, 0.024030398577451706,...
# 117  [[0.009475408121943474, -0.02955947257578373, ...
# 118  [[-0.03955880180001259, -0.02995660901069641, ...
# 119  [[0.018003923818469048, -0.020617587491869926,...
# 120  [[-0.05790490657091141, 0.001216510427184403, ...
#
# [121 rows x 2 columns]

# %% [markdown]
# # Feature Extraction using SXG on Word2Vec Embeddings

# %%
def calculate_sxgbg_stan_features(evolutionary_profile, X):
    L, _ = evolutionary_profile.shape
    sxgbg_matrix = np.zeros((20, 20))

    for i in range(20):
        for j in range(20):
            sxgbg_value = 0.0

            for l in range(1, L - X):
                sxgbg_value += evolutionary_profile[l - 1, i] * evolutionary_profile[l + X, j]

            sxgbg_matrix[i, j] = sxgbg_value

    # Standardize the sxgbg_matrix (z-score normalization)
    mean = np.mean(sxgbg_matrix)
    std = np.std(sxgbg_matrix)

    if std != 0:
        sxgbg_matrix = (sxgbg_matrix - mean) / std
    else:
        sxgbg_matrix = np.zeros_like(sxgbg_matrix)  # Handle the case of zero standard deviation

    return sxgbg_matrix

# %% [markdown]
# **S0G on bi-gram embeddings**

# %%
import numpy as np

# Create an empty list to store hmm_arr for each PDBid
s0g_matrix_2g = []

for i in df['2gramembeddings']:
    s0g_mat_2g = calculate_sxgbg_stan_features(np.array(i), 0)
    s0g_arr_2g = np.array(s0g_mat_2g)
    s0g_matrix_2g.append(s0g_arr_2g)

df['s0g_matrix_2g'] = s0g_matrix_2g

# %% [markdown]
# **S1G on bi-gram embeddings**

# %%
# Create an empty list to store hmm_arr for each PDBid
s1g_matrix_2g = []

for i in df['2gramembeddings']:
    s1g_mat_2g = calculate_sxgbg_stan_features(np.array(i), 1)
    s1g_arr_2g = np.array(s1g_mat_2g)
    s1g_matrix_2g.append(s1g_arr_2g)

df['s1g_matrix_2g'] = s1g_matrix_2g

# %% [markdown]
# **S2G on bi-gram embeddings**

# %%
# Create an empty list to store hmm_arr for each PDBid
s2g_matrix_2g = []

for i in df['2gramembeddings']:
    s2g_mat_2g = calculate_sxgbg_stan_features(np.array(i), 2)
    s2g_arr_2g = np.array(s2g_mat_2g)
    s2g_matrix_2g.append(s2g_arr_2g)

df['s2g_matrix_2g'] = s2g_matrix_2g

# %% [markdown]
# **S3G on bi-gram embeddings**

# %%
# Create an empty list to store hmm_arr for each PDBid
s3g_matrix_2g = []

for i in df['2gramembeddings']:
    s3g_mat_2g = calculate_sxgbg_stan_features(np.array(i), 3)
    s3g_arr_2g = np.array(s3g_mat_2g)
    s3g_matrix_2g.append(s3g_arr_2g)

df['s3g_matrix_2g'] = s3g_matrix_2g

# %% [markdown]
# **S4G on bi-gram embeddings**

# %%
# Create an empty list to store hmm_arr for each PDBid
s4g_matrix_2g = []

for i in df['2gramembeddings']:
    s4g_mat_2g = calculate_sxgbg_stan_features(np.array(i), 4)
    s4g_arr_2g = np.array(s4g_mat_2g)
    s4g_matrix_2g.append(s4g_arr_2g)

df['s4g_matrix_2g'] = s4g_matrix_2g

# %% [markdown]
# **S0G on Tri-gram embeddings**

# %%
import numpy as np

# Create an empty list to store hmm_arr for each PDBid
s0g_matrix_3gram = []

for i in df['3gramembeddings']:
    s0g_mat_3 = calculate_sxgbg_stan_features(np.array(i), 0)
    s0g_arr_3 = np.array(s0g_mat_3)
    s0g_matrix_3gram.append(s0g_arr_3)

df['s0g_matrix_3gram'] = s0g_matrix_3gram

# %% [markdown]
# **S1G on Tri-gram embeddings**

# %%
# Create an empty list to store hmm_arr for each PDBid
s1g_matrix_3gram = []

for i in df['3gramembeddings']:
    s1g_mat_3 = calculate_sxgbg_stan_features(np.array(i), 1)
    s1g_arr_3 = np.array(s1g_mat_3)
    s1g_matrix_3gram.append(s1g_arr_3)

df['s1g_matrix_3gram'] = s1g_matrix_3gram

# %% [markdown]
# **S2G on Tri-gram embeddings**

# %%
# Create an empty list to store hmm_arr for each PDBid
s2g_matrix_3gram = []

for i in df['3gramembeddings']:
    s2g_mat_3 = calculate_sxgbg_stan_features(np.array(i), 2)
    s2g_arr_3 = np.array(s2g_mat_3)
    s2g_matrix_3gram.append(s2g_arr_3)

df['s2g_matrix_3gram'] = s2g_matrix_3gram

# %% [markdown]
# **S0G on 4-gram embeddings**

# %%
import numpy as np

# Create an empty list to store hmm_arr for each PDBid
s0g_matrix_4gram = []

for i in df['4gramembeddings']:
    s0g_mat_4 = calculate_sxgbg_stan_features(np.array(i), 0)
    s0g_arr_4 = np.array(s0g_mat_4)
    s0g_matrix_4gram.append(s0g_arr_4)

df['s0g_matrix_4gram'] = s0g_matrix_4gram

# %% [markdown]
# **S1G on 4-gram embeddings**

# %%
import numpy as np

# Create an empty list to store hmm_arr for each PDBid
s1g_matrix_4gram = []

for i in df['4gramembeddings']:
    s1g_mat_4 = calculate_sxgbg_stan_features(np.array(i), 1)
    s1g_arr_4 = np.array(s1g_mat_4)
    s1g_matrix_4gram.append(s1g_arr_4)

df['s1g_matrix_4gram'] = s1g_matrix_4gram

# %% [markdown]
# # Evaluation Metrics

# %%
def calculate_accuracy(y_true, y_pred):
    # Ensure inputs are numpy arrays
    y_true = np.array(y_true)
    y_pred = np.array((y_pred>0.5).astype(int))

    # Initialize accuracy
    accuracy = 0

    # Calculate accuracy for each instance
    for i in range(len(y_true)):
        # Calculate intersection and union
        intersection = np.sum(np.logical_and(y_true[i], y_pred[i]))
        union = np.sum(np.logical_or(y_true[i], y_pred[i]))

        # Add to total accuracy
        accuracy += intersection / union

    # Calculate average accuracy
    accuracy /= len(y_true)

    return accuracy

# %%
import numpy as np

def norm_accuracy(y_true, y_pred):
    # Ensure inputs are numpy arrays
    y_true = np.array(y_true)
    y_pred = np.array((y_pred>0.5).astype(int))

    acc = []
    # Loop over each instance
    for i in range(len(y_true)):
        # Calculate the number of correct predictions for this instance
        correct_predictions = np.sum(y_true[i] == y_pred[i])
        acc.append(correct_predictions/5)

    # Calculate accuracy
    accuracy = sum(acc) / len(y_true)

    return accuracy

# %% [markdown]
# # Models

# %% [markdown]
# **bi-gram+S0G Matrix Model**

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import KFold
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau

# Define the model
model_s0g = keras.Sequential([
    keras.layers.Input(shape=(None, 400)),
    keras.layers.Dense(400, activation='relu',kernel_initializer='he_normal'),
    keras.layers.Dense(100, activation='relu',kernel_initializer='he_normal'),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(25, activation='relu',kernel_initializer='he_normal'),
    keras.layers.Dense(5, activation='sigmoid')
])

# Load your data and preprocess it
train_features = np.array(df['s0g_matrix_2g'].tolist())
train_labels = np.array(df[['envelope', 'lumen', 'plastoglobule', 'stroma', 'thylakoid_membrane']].values)

train_features = train_features.reshape(-1, 400)

# Initialize K-Fold cross-validator
kf = KFold(n_splits=5)

# Initialize a list to store accuracy scores
accuracy_scores = []
precision_scores = []
recall_scores = []
acc_scores = []
acc_norm = []

# Iterate over each sample for LOOCV
for train_index, test_index in kf.split(train_features):
    X_train, X_test = train_features[train_index], train_features[test_index]
    y_train, y_test = train_labels[train_index], train_labels[test_index]

    # Compile the model and set up callbacks (as in your code)
    model_s0g.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    early_stopping = EarlyStopping(monitor='val_accuracy', min_delta=0.00005, patience=5, verbose=1, restore_best_weights=True)
    lr_scheduler = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=3, min_lr=1e-6, verbose=1)
    callbacks = [early_stopping, lr_scheduler]

    batch_size = 2
    model_s0g.fit(X_train, y_train, epochs=15, validation_data=(X_test, y_test), batch_size=batch_size, callbacks=callbacks)

    # Make predictions on the current test sample
    y_pred = model_s0g.predict(X_test)


    # Calculate and store the accuracy for this fold
    accuracy = accuracy_score(y_test, (y_pred > 0.5).astype(int))
    precision = precision_score(y_test, (y_pred > 0.5).astype(int), average='weighted')
    recall = recall_score(y_test, (y_pred > 0.5).astype(int), average='weighted')
    accuracy_scores.append(accuracy)
    precision_scores.append(precision)
    recall_scores.append(recall)
    acc_scores.append(norm_accuracy(y_test, y_pred))
    acc_norm.append(calculate_accuracy(y_test, y_pred))

# Calculate the average accuracy across all folds
average_accuracy = sum(accuracy_scores) / len(accuracy_scores)
avg_precision = sum(precision_scores) / len(precision_scores)
avg_acc_norm = sum(acc_norm)/len(acc_norm)
avg_recall = sum(recall_scores) / len(recall_scores)
avg_acc = sum(acc_scores)/len(acc_scores)
f1 = 2 * (avg_precision * avg_recall) / (avg_precision + avg_recall)
grand_mean=(average_accuracy+avg_precision+avg_recall+f1+avg_acc_norm++avg_acc)/6
# Print the average accuracy
print("Average Accuracy: ", average_accuracy)
print("Accuracy: ", avg_acc)
print("Average Normalized Accuracy: ", avg_acc_norm)
print("Average Precision: ", avg_precision)
print("Average Recall: ", avg_recall)
print('F1 score:', f1)
print('Grand Mean:', grand_mean)
# Out:
# Epoch 1/15
# 48/48 [==============================] - 1s 9ms/step - loss: 0.5079 - accuracy: 0.4271 - val_loss: 0.4218 - val_accuracy: 0.5600 - lr: 0.0010
# Epoch 2/15
# 48/48 [==============================] - 0s 5ms/step - loss: 0.4293 - accuracy: 0.5104 - val_loss: 0.3966 - val_accuracy: 0.5600 - lr: 0.0010
# Epoch 3/15
# 48/48 [==============================] - 0s 5ms/step - loss: 0.4027 - accuracy: 0.5312 - val_loss: 0.3414 - val_accuracy: 0.5600 - lr: 0.0010
# Epoch 4/15
# 48/48 [==============================] - 0s 5ms/step - loss: 0.3933 - accuracy: 0.5521 - val_loss: 0.3340 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 5/15
# 48/48 [==============================] - 0s 5ms/step - loss: 0.3506 - accuracy: 0.6354 - val_loss: 0.3601 - val_accuracy: 0.5600 - lr: 0.0010
# Epoch 6/15
# 48/48 [==============================] - 0s 5ms/step - loss: 0.3438 - accuracy: 0.5729 - val_loss: 0.3569 - val_accuracy: 0.5200 - lr: 0.0010
# Epoch 7/15
# 42/48 [=========================>....] - ETA: 0s - loss: 0.3004 - accuracy: 0.7024
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 48/48 [==============================] - 0s 5ms/step - loss: 0.2891 - accuracy: 0.7083 - val_loss: 0.4110 - val_accuracy: 0.5600 - lr: 0.0010
# Epoch 8/15
# 48/48 [==============================] - 0s 5ms/step - loss: 0.2657 - accuracy: 0.6875 - val_loss: 0.3148 - val_accuracy: 0.6000 - lr: 5.0000e-04
# Epoch 9/15
# 44/48 [==========================>...] - ETA: 0s - loss: 0.2249 - accuracy: 0.7841Restoring model weights from the end of the best epoch: 4.
# 48/48 [==============================] - 0s 5ms/step - loss: 0.2365 - accuracy: 0.7604 - val_loss: 0.3375 - val_accuracy: 0.5600 - lr: 5.0000e-04
# Epoch 9: early stopping
# 1/1 [==============================] - 0s 94ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 1s 8ms/step - loss: 0.3830 - accuracy: 0.5361 - val_loss: 0.3312 - val_accuracy: 0.6250 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.4238 - accuracy: 0.4536 - val_loss: 0.3546 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.3417 - accuracy: 0.6392 - val_loss: 0.3271 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 4/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.3114 - accuracy: 0.6392 - val_loss: 0.2810 - val_accuracy: 0.7917 - lr: 0.0010
# Epoch 5/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.2784 - accuracy: 0.7010 - val_loss: 0.2807 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 6/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.2863 - accuracy: 0.6701 - val_loss: 0.2547 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 7/15
# 49/49 [==============================] - 0s 6ms/step - loss: 0.2460 - accuracy: 0.7216 - val_loss: 0.2519 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 8/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1928 - accuracy: 0.8041 - val_loss: 0.2488 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 9/15
# 42/49 [========================>.....] - ETA: 0s - loss: 0.1766 - accuracy: 0.8929
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1849 - accuracy: 0.8660 - val_loss: 0.2364 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 10/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1428 - accuracy: 0.8866 - val_loss: 0.2524 - val_accuracy: 0.7917 - lr: 5.0000e-04
# Epoch 11/15
# 42/49 [========================>.....] - ETA: 0s - loss: 0.0927 - accuracy: 0.9286Restoring model weights from the end of the best epoch: 6.
# 49/49 [==============================] - 0s 8ms/step - loss: 0.1139 - accuracy: 0.9072 - val_loss: 0.2450 - val_accuracy: 0.8333 - lr: 5.0000e-04
# Epoch 11: early stopping
# 1/1 [==============================] - 0s 93ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 1s 8ms/step - loss: 0.2678 - accuracy: 0.7423 - val_loss: 0.1724 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.2510 - accuracy: 0.7526 - val_loss: 0.2202 - val_accuracy: 0.7083 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.2248 - accuracy: 0.7732 - val_loss: 0.1597 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 4/15
# 41/49 [========================>.....] - ETA: 0s - loss: 0.1762 - accuracy: 0.8171
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1769 - accuracy: 0.8144 - val_loss: 0.1927 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 5/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1531 - accuracy: 0.8866 - val_loss: 0.1384 - val_accuracy: 0.8333 - lr: 5.0000e-04
# Epoch 6/15
# 44/49 [=========================>....] - ETA: 0s - loss: 0.1279 - accuracy: 0.8864Restoring model weights from the end of the best epoch: 1.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1297 - accuracy: 0.8866 - val_loss: 0.1795 - val_accuracy: 0.7917 - lr: 5.0000e-04
# Epoch 6: early stopping
# 1/1 [==============================] - 0s 70ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 1s 8ms/step - loss: 0.2986 - accuracy: 0.6598 - val_loss: 0.1957 - val_accuracy: 0.7917 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.2109 - accuracy: 0.8041 - val_loss: 0.1723 - val_accuracy: 0.9167 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1847 - accuracy: 0.7938 - val_loss: 0.1710 - val_accuracy: 0.7917 - lr: 0.0010
# Epoch 4/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1696 - accuracy: 0.8041 - val_loss: 0.1981 - val_accuracy: 0.7917 - lr: 0.0010
# Epoch 5/15
# 37/49 [=====================>........] - ETA: 0s - loss: 0.1273 - accuracy: 0.9054
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1596 - accuracy: 0.8454 - val_loss: 0.2063 - val_accuracy: 0.7917 - lr: 0.0010
# Epoch 6/15
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1301 - accuracy: 0.9072 - val_loss: 0.1461 - val_accuracy: 0.8750 - lr: 5.0000e-04
# Epoch 7/15
# 38/49 [======================>.......] - ETA: 0s - loss: 0.1054 - accuracy: 0.9079Restoring model weights from the end of the best epoch: 2.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1040 - accuracy: 0.9175 - val_loss: 0.1549 - val_accuracy: 0.8750 - lr: 5.0000e-04
# Epoch 7: early stopping
# 1/1 [==============================] - 0s 66ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 2s 9ms/step - loss: 0.2252 - accuracy: 0.7423 - val_loss: 0.1699 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1481 - accuracy: 0.8660 - val_loss: 0.1916 - val_accuracy: 0.7083 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1704 - accuracy: 0.8557 - val_loss: 0.1901 - val_accuracy: 0.7917 - lr: 0.0010
# Epoch 4/15
# 44/49 [=========================>....] - ETA: 0s - loss: 0.1345 - accuracy: 0.8750
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1359 - accuracy: 0.8660 - val_loss: 0.2503 - val_accuracy: 0.7917 - lr: 0.0010
# Epoch 5/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1056 - accuracy: 0.9072 - val_loss: 0.1958 - val_accuracy: 0.7917 - lr: 5.0000e-04
# Epoch 6/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0887 - accuracy: 0.9278 - val_loss: 0.1540 - val_accuracy: 0.9167 - lr: 5.0000e-04
# Epoch 7/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0742 - accuracy: 0.9381 - val_loss: 0.1922 - val_accuracy: 0.7500 - lr: 5.0000e-04
# Epoch 8/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0621 - accuracy: 0.9381 - val_loss: 0.1463 - val_accuracy: 0.9167 - lr: 5.0000e-04
# Epoch 9/15
# 40/49 [=======================>......] - ETA: 0s - loss: 0.0495 - accuracy: 0.9250
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0536 - accuracy: 0.9175 - val_loss: 0.1625 - val_accuracy: 0.8333 - lr: 5.0000e-04
# Epoch 10/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0485 - accuracy: 0.9278 - val_loss: 0.1481 - val_accuracy: 0.9167 - lr: 2.5000e-04
# Epoch 11/15
# 42/49 [========================>.....] - ETA: 0s - loss: 0.0369 - accuracy: 0.9524Restoring model weights from the end of the best epoch: 6.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0367 - accuracy: 0.9588 - val_loss: 0.1549 - val_accuracy: 0.8750 - lr: 2.5000e-04
# Epoch 11: early stopping
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7872dbb7c700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 67ms/step
# Average Accuracy:  0.622
# Accuracy:  0.9077333333333335
# Average Normalized Accuracy:  0.6511666666666667
# Average Precision:  0.799967032967033
# Average Recall:  0.6230989010989012
# F1 score: 0.7005417911072164
# Grand Mean: 0.7174179541955251
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# **2-gram+S1G Matrix Model**

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import KFold
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau

# Define the model
model_s1g = keras.Sequential([
    keras.layers.Input(shape=(None, 400)),
    keras.layers.Dense(400, activation='relu',kernel_initializer='he_normal'),
    keras.layers.Dense(100, activation='relu',kernel_initializer='he_normal'),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(25, activation='relu',kernel_initializer='he_normal'),
    keras.layers.Dense(5, activation='sigmoid')
])

# Load your data and preprocess it
train_features = np.array(df['s1g_matrix_2g'].tolist())
train_labels = np.array(df[['envelope', 'lumen', 'plastoglobule', 'stroma', 'thylakoid_membrane']].values)

train_features = train_features.reshape(-1, 400)

# Initialize K-Fold cross-validator
kf = KFold(n_splits=5)

# Initialize a list to store accuracy scores
accuracy_scores = []
precision_scores = []
recall_scores = []
acc_scores = []
acc_norm = []

# Iterate over each sample for LOOCV
for train_index, test_index in kf.split(train_features):
    X_train, X_test = train_features[train_index], train_features[test_index]
    y_train, y_test = train_labels[train_index], train_labels[test_index]

    # Compile the model and set up callbacks (as in your code)
    model_s1g.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    early_stopping = EarlyStopping(monitor='val_accuracy', min_delta=0.00005, patience=5, verbose=1, restore_best_weights=True)
    lr_scheduler = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=3, min_lr=1e-6, verbose=1)
    callbacks = [early_stopping, lr_scheduler]

    batch_size = 2
    model_s1g.fit(X_train, y_train, epochs=15, validation_data=(X_test, y_test), batch_size=batch_size, callbacks=callbacks)

    # Make predictions on the current test sample
    y_pred = model_s1g.predict(X_test)


    # Calculate and store the accuracy for this fold
    accuracy = accuracy_score(y_test, (y_pred > 0.5).astype(int))
    precision = precision_score(y_test, (y_pred > 0.5).astype(int), average='weighted')
    recall = recall_score(y_test, (y_pred > 0.5).astype(int), average='weighted')
    accuracy_scores.append(accuracy)
    precision_scores.append(precision)
    recall_scores.append(recall)
    acc_scores.append(norm_accuracy(y_test, y_pred))
    acc_norm.append(calculate_accuracy(y_test, y_pred))

# Calculate the average accuracy across all folds
average_accuracy = sum(accuracy_scores) / len(accuracy_scores)
avg_precision = sum(precision_scores) / len(precision_scores)
avg_acc_norm = sum(acc_norm)/len(acc_norm)
avg_recall = sum(recall_scores) / len(recall_scores)
avg_acc = sum(acc_scores)/len(acc_scores)
f1 = 2 * (avg_precision * avg_recall) / (avg_precision + avg_recall)
grand_mean=(average_accuracy+avg_precision+avg_recall+f1+avg_acc_norm++avg_acc)/6
# Print the average accuracy
print("Average Accuracy: ", average_accuracy)
print("Accuracy: ", avg_acc)
print("Average Normalized Accuracy: ", avg_acc_norm)
print("Average Precision: ", avg_precision)
print("Average Recall: ", avg_recall)
print('F1 score:', f1)
print('Grand Mean:', grand_mean)
# Out:
# Epoch 1/15
# 48/48 [==============================] - 2s 15ms/step - loss: 0.5567 - accuracy: 0.3542 - val_loss: 0.3881 - val_accuracy: 0.5600 - lr: 0.0010
# Epoch 2/15
# 48/48 [==============================] - 0s 9ms/step - loss: 0.3060 - accuracy: 0.7188 - val_loss: 0.3375 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 3/15
# 48/48 [==============================] - 0s 9ms/step - loss: 0.1516 - accuracy: 0.8750 - val_loss: 0.3769 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 4/15
# 48/48 [==============================] - 0s 9ms/step - loss: 0.0884 - accuracy: 0.9167 - val_loss: 0.3904 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 5/15
# 47/48 [============================>.] - ETA: 0s - loss: 0.0588 - accuracy: 0.9362
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 48/48 [==============================] - 0s 9ms/step - loss: 0.0577 - accuracy: 0.9375 - val_loss: 0.4569 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 6/15
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0309 - accuracy: 0.9583 - val_loss: 0.4709 - val_accuracy: 0.6000 - lr: 5.0000e-04
# Epoch 7/15
# 44/48 [==========================>...] - ETA: 0s - loss: 0.0358 - accuracy: 0.9773Restoring model weights from the end of the best epoch: 2.
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0336 - accuracy: 0.9792 - val_loss: 0.4947 - val_accuracy: 0.6000 - lr: 5.0000e-04
# Epoch 7: early stopping
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7872d96c3490> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 68ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 1s 8ms/step - loss: 0.2181 - accuracy: 0.7732 - val_loss: 0.1525 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1473 - accuracy: 0.8660 - val_loss: 0.1816 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0910 - accuracy: 0.9278 - val_loss: 0.2599 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 4/15
# 38/49 [======================>.......] - ETA: 0s - loss: 0.0604 - accuracy: 0.9737
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0604 - accuracy: 0.9794 - val_loss: 0.2150 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 5/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0359 - accuracy: 0.9485 - val_loss: 0.2043 - val_accuracy: 0.7083 - lr: 5.0000e-04
# Epoch 6/15
# 40/49 [=======================>......] - ETA: 0s - loss: 0.0213 - accuracy: 0.9250Restoring model weights from the end of the best epoch: 1.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0203 - accuracy: 0.9381 - val_loss: 0.2103 - val_accuracy: 0.7500 - lr: 5.0000e-04
# Epoch 6: early stopping
# 1/1 [==============================] - 0s 66ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 1s 8ms/step - loss: 0.1910 - accuracy: 0.8144 - val_loss: 0.0757 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0701 - accuracy: 0.9175 - val_loss: 0.0860 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0444 - accuracy: 0.9691 - val_loss: 0.0860 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 4/15
# 43/49 [=========================>....] - ETA: 0s - loss: 0.0343 - accuracy: 0.9651
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0310 - accuracy: 0.9691 - val_loss: 0.1076 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 5/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0201 - accuracy: 0.9588 - val_loss: 0.0841 - val_accuracy: 0.8750 - lr: 5.0000e-04
# Epoch 6/15
# 39/49 [======================>.......] - ETA: 0s - loss: 0.0199 - accuracy: 0.9615Restoring model weights from the end of the best epoch: 1.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0224 - accuracy: 0.9691 - val_loss: 0.0867 - val_accuracy: 0.9167 - lr: 5.0000e-04
# Epoch 6: early stopping
# 1/1 [==============================] - 0s 71ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 1s 8ms/step - loss: 0.1168 - accuracy: 0.8660 - val_loss: 0.0544 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0523 - accuracy: 0.9485 - val_loss: 0.0268 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0212 - accuracy: 0.9691 - val_loss: 0.0499 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 4/15
# 47/49 [===========================>..] - ETA: 0s - loss: 0.0276 - accuracy: 0.9574
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0270 - accuracy: 0.9485 - val_loss: 0.0767 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 5/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0172 - accuracy: 0.9691 - val_loss: 0.0780 - val_accuracy: 0.8750 - lr: 5.0000e-04
# Epoch 6/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0138 - accuracy: 0.9381 - val_loss: 0.0788 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 7/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0087 - accuracy: 0.9588 - val_loss: 0.0813 - val_accuracy: 0.9167 - lr: 5.0000e-04
# Epoch 8/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0039 - accuracy: 0.9588 - val_loss: 0.0969 - val_accuracy: 0.8750 - lr: 5.0000e-04
# Epoch 9/15
# 42/49 [========================>.....] - ETA: 0s - loss: 0.0023 - accuracy: 0.9881
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0046 - accuracy: 0.9794 - val_loss: 0.0993 - val_accuracy: 0.9167 - lr: 5.0000e-04
# Epoch 10/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0049 - accuracy: 0.9794 - val_loss: 0.0991 - val_accuracy: 0.9167 - lr: 2.5000e-04
# Epoch 11/15
# 40/49 [=======================>......] - ETA: 0s - loss: 0.0043 - accuracy: 0.9750Restoring model weights from the end of the best epoch: 6.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0049 - accuracy: 0.9794 - val_loss: 0.0975 - val_accuracy: 0.9167 - lr: 2.5000e-04
# Epoch 11: early stopping
# 1/1 [==============================] - 0s 111ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 2s 14ms/step - loss: 0.0668 - accuracy: 0.9278 - val_loss: 0.0027 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0063 - accuracy: 0.9691 - val_loss: 0.0053 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0024 - accuracy: 0.9794 - val_loss: 0.0084 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 4/15
# 43/49 [=========================>....] - ETA: 0s - loss: 0.0017 - accuracy: 0.9651
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0016 - accuracy: 0.9691 - val_loss: 0.0104 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 5/15
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0040 - accuracy: 0.9794 - val_loss: 0.0037 - val_accuracy: 0.9583 - lr: 5.0000e-04
# Epoch 6/15
# 40/49 [=======================>......] - ETA: 0s - loss: 0.0030 - accuracy: 0.9500Restoring model weights from the end of the best epoch: 1.
# 49/49 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 0.9485 - val_loss: 0.0040 - val_accuracy: 0.9583 - lr: 5.0000e-04
# Epoch 6: early stopping
# 1/1 [==============================] - 0s 66ms/step
# Average Accuracy:  0.7876666666666667
# Accuracy:  0.9495333333333335
# Average Normalized Accuracy:  0.8057222222222222
# Average Precision:  0.8448141858141858
# Average Recall:  0.8273186813186812
# F1 score: 0.8359749059481536
# Grand Mean: 0.8418383325505404
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# **Bi-gram+S2G Matrix Model**

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import KFold
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau

# Define the model
model_s2g = keras.Sequential([
    keras.layers.Input(shape=(None, 400)),
    keras.layers.Dense(400, activation='relu',kernel_initializer='he_normal'),
    keras.layers.Dense(100, activation='relu',kernel_initializer='he_normal'),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(25, activation='relu',kernel_initializer='he_normal'),
    keras.layers.Dense(5, activation='sigmoid')
])

# Load your data and preprocess it
train_features = np.array(df['s2g_matrix_2g'].tolist())
train_labels = np.array(df[['envelope', 'lumen', 'plastoglobule', 'stroma', 'thylakoid_membrane']].values)

train_features = train_features.reshape(-1, 400)

# Initialize K-Fold cross-validator
kf = KFold(n_splits=5)

# Initialize a list to store accuracy scores
accuracy_scores = []
precision_scores = []
recall_scores = []
acc_scores = []
acc_norm = []

# Iterate over each sample for LOOCV
for train_index, test_index in kf.split(train_features):
    X_train, X_test = train_features[train_index], train_features[test_index]
    y_train, y_test = train_labels[train_index], train_labels[test_index]

    # Compile the model and set up callbacks (as in your code)
    model_s2g.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    early_stopping = EarlyStopping(monitor='val_accuracy', min_delta=0.00005, patience=5, verbose=1, restore_best_weights=True)
    lr_scheduler = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=3, min_lr=1e-6, verbose=1)
    callbacks = [early_stopping, lr_scheduler]

    batch_size = 2
    model_s2g.fit(X_train, y_train, epochs=15, validation_data=(X_test, y_test), batch_size=batch_size, callbacks=callbacks)

    # Make predictions on the current test sample
    y_pred = model_s2g.predict(X_test)


    # Calculate and store the accuracy for this fold
    accuracy = accuracy_score(y_test, (y_pred > 0.5).astype(int))
    precision = precision_score(y_test, (y_pred > 0.5).astype(int), average='weighted')
    recall = recall_score(y_test, (y_pred > 0.5).astype(int), average='weighted')
    accuracy_scores.append(accuracy)
    precision_scores.append(precision)
    recall_scores.append(recall)
    acc_scores.append(norm_accuracy(y_test, y_pred))
    acc_norm.append(calculate_accuracy(y_test, y_pred))

# Calculate the average accuracy across all folds
average_accuracy = sum(accuracy_scores) / len(accuracy_scores)
avg_precision = sum(precision_scores) / len(precision_scores)
avg_acc_norm = sum(acc_norm)/len(acc_norm)
avg_recall = sum(recall_scores) / len(recall_scores)
avg_acc = sum(acc_scores)/len(acc_scores)
f1 = 2 * (avg_precision * avg_recall) / (avg_precision + avg_recall)
grand_mean=(average_accuracy+avg_precision+avg_recall+f1+avg_acc_norm++avg_acc)/6
# Print the average accuracy
print("Average Accuracy: ", average_accuracy)
print("Accuracy: ", avg_acc)
print("Average Normalized Accuracy: ", avg_acc_norm)
print("Average Precision: ", avg_precision)
print("Average Recall: ", avg_recall)
print('F1 score:', f1)
print('Grand Mean:', grand_mean)
# Out:
# Epoch 1/15
# 48/48 [==============================] - 1s 8ms/step - loss: 0.5283 - accuracy: 0.4062 - val_loss: 0.3842 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 2/15
# 48/48 [==============================] - 0s 6ms/step - loss: 0.2930 - accuracy: 0.7188 - val_loss: 0.3140 - val_accuracy: 0.6800 - lr: 0.0010
# Epoch 3/15
# 48/48 [==============================] - 0s 5ms/step - loss: 0.1778 - accuracy: 0.8542 - val_loss: 0.3523 - val_accuracy: 0.6800 - lr: 0.0010
# Epoch 4/15
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0980 - accuracy: 0.9271 - val_loss: 0.3784 - val_accuracy: 0.6800 - lr: 0.0010
# Epoch 5/15
# 41/48 [========================>.....] - ETA: 0s - loss: 0.0800 - accuracy: 0.9390
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0744 - accuracy: 0.9167 - val_loss: 0.4383 - val_accuracy: 0.6400 - lr: 0.0010
# Epoch 6/15
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0607 - accuracy: 0.9271 - val_loss: 0.4455 - val_accuracy: 0.6800 - lr: 5.0000e-04
# Epoch 7/15
# 38/48 [======================>.......] - ETA: 0s - loss: 0.0254 - accuracy: 0.9737Restoring model weights from the end of the best epoch: 2.
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0248 - accuracy: 0.9583 - val_loss: 0.4777 - val_accuracy: 0.6800 - lr: 5.0000e-04
# Epoch 7: early stopping
# 1/1 [==============================] - 0s 64ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 1s 9ms/step - loss: 0.2580 - accuracy: 0.7216 - val_loss: 0.1597 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1743 - accuracy: 0.7938 - val_loss: 0.1674 - val_accuracy: 0.7917 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0796 - accuracy: 0.9278 - val_loss: 0.1460 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 4/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0581 - accuracy: 0.9175 - val_loss: 0.1269 - val_accuracy: 0.9167 - lr: 0.0010
# Epoch 5/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0318 - accuracy: 0.9485 - val_loss: 0.1497 - val_accuracy: 0.7917 - lr: 0.0010
# Epoch 6/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0370 - accuracy: 0.9175 - val_loss: 0.2421 - val_accuracy: 0.7083 - lr: 0.0010
# Epoch 7/15
# 46/49 [===========================>..] - ETA: 0s - loss: 0.0191 - accuracy: 0.9348
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0199 - accuracy: 0.9381 - val_loss: 0.1580 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 8/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0166 - accuracy: 0.9588 - val_loss: 0.1342 - val_accuracy: 0.7083 - lr: 5.0000e-04
# Epoch 9/15
# 41/49 [========================>.....] - ETA: 0s - loss: 0.0143 - accuracy: 0.9268Restoring model weights from the end of the best epoch: 4.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0129 - accuracy: 0.9381 - val_loss: 0.1757 - val_accuracy: 0.7083 - lr: 5.0000e-04
# Epoch 9: early stopping
# 1/1 [==============================] - 0s 65ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 2s 14ms/step - loss: 0.0941 - accuracy: 0.8866 - val_loss: 0.0272 - val_accuracy: 0.9167 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0315 - accuracy: 0.9588 - val_loss: 0.0242 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0175 - accuracy: 0.9588 - val_loss: 0.0259 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 4/15
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0122 - accuracy: 0.9794 - val_loss: 0.0235 - val_accuracy: 0.9167 - lr: 0.0010
# Epoch 5/15
# 48/49 [============================>.] - ETA: 0s - loss: 0.0038 - accuracy: 0.9792
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0038 - accuracy: 0.9794 - val_loss: 0.0261 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 6/15
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0037 - accuracy: 0.9897 - val_loss: 0.0306 - val_accuracy: 0.9167 - lr: 5.0000e-04
# Epoch 7/15
# 41/49 [========================>.....] - ETA: 0s - loss: 0.0020 - accuracy: 0.9512Restoring model weights from the end of the best epoch: 2.
# 49/49 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 0.9588 - val_loss: 0.0296 - val_accuracy: 0.9167 - lr: 5.0000e-04
# Epoch 7: early stopping
# 1/1 [==============================] - 0s 69ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 1s 8ms/step - loss: 0.0379 - accuracy: 0.9175 - val_loss: 0.0032 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0148 - accuracy: 0.9691 - val_loss: 0.0021 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0222 - accuracy: 0.9381 - val_loss: 0.0027 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 4/15
# 49/49 [==============================] - ETA: 0s - loss: 0.0136 - accuracy: 0.9794
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0136 - accuracy: 0.9794 - val_loss: 0.0038 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 5/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0066 - accuracy: 0.9691 - val_loss: 0.0030 - val_accuracy: 0.9583 - lr: 5.0000e-04
# Epoch 6/15
# 46/49 [===========================>..] - ETA: 0s - loss: 0.0139 - accuracy: 0.9674Restoring model weights from the end of the best epoch: 1.
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0136 - accuracy: 0.9691 - val_loss: 0.0020 - val_accuracy: 0.9167 - lr: 5.0000e-04
# Epoch 6: early stopping
# 1/1 [==============================] - 0s 70ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 1s 9ms/step - loss: 0.0183 - accuracy: 0.9588 - val_loss: 0.0020 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0152 - accuracy: 0.9381 - val_loss: 0.0019 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0116 - accuracy: 0.9485 - val_loss: 0.0079 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 4/15
# 46/49 [===========================>..] - ETA: 0s - loss: 0.0094 - accuracy: 0.9457
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0090 - accuracy: 0.9485 - val_loss: 0.0119 - val_accuracy: 0.9167 - lr: 0.0010
# Epoch 5/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0045 - accuracy: 0.9278 - val_loss: 0.0033 - val_accuracy: 0.9583 - lr: 5.0000e-04
# Epoch 6/15
# 49/49 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9485Restoring model weights from the end of the best epoch: 1.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0011 - accuracy: 0.9485 - val_loss: 0.0025 - val_accuracy: 0.9167 - lr: 5.0000e-04
# Epoch 6: early stopping
# 1/1 [==============================] - 0s 70ms/step
# Average Accuracy:  0.8620000000000001
# Accuracy:  0.9676
# Average Normalized Accuracy:  0.8785000000000001
# Average Precision:  0.9184322344322343
# Average Recall:  0.8969230769230769
# F1 score: 0.9075502305246126
# Grand Mean: 0.9051675903133206
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# bigram s2g - lstm

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau

# Define the model
model_lstmsn = keras.Sequential([
    keras.layers.Input(shape=(400,1)),
    keras.layers.LSTM(256, return_sequences=True, kernel_initializer = 'he_normal'),
    keras.layers.LSTM(128, return_sequences=True, kernel_initializer = 'he_normal'),  # Another LSTM layer with 64 units
    keras.layers.Flatten(),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(64, activation='relu', kernel_initializer = 'he_normal'),     # Fully connected layer
    keras.layers.Dense(5, activation='sigmoid')    # Output layer with sigmoid activation for multi-label classification
])

train_features = np.array(df['s2g_matrix_2g'].tolist())
train_features = train_features.reshape(-1, 400,1)

train_labels = np.array(df[['envelope', 'lumen', 'plastoglobule', 'stroma', 'thylakoid_membrane']].values)

# Initialize K-Fold cross-validator
kf = KFold(n_splits=5)

# Initialize a list to store accuracy scores
accuracy_scores = []
precision_scores = []
recall_scores = []
acc_scores = []
acc_norm = []

# Iterate over each sample for LOOCV
for train_index, test_index in kf.split(train_features):
    X_train, X_test = train_features[train_index], train_features[test_index]
    y_train, y_test = train_labels[train_index], train_labels[test_index]

    # Compile the model and set up callbacks (as in your code)
    model_lstmsn.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    early_stopping = EarlyStopping(monitor='val_accuracy', min_delta=0.00005, patience=7, verbose=1, restore_best_weights=True)
    lr_scheduler = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=4, min_lr=1e-6, verbose=1)
    callbacks = [early_stopping, lr_scheduler]

    batch_size = 2
    model_lstmsn.fit(X_train, y_train, epochs=15, validation_data=(X_test, y_test), batch_size=batch_size, callbacks=callbacks)

    # Make predictions on the current test sample
    y_pred = model_lstmsn.predict(X_test)


    # Calculate and store the accuracy for this fold
    accuracy = accuracy_score(y_test, (y_pred > 0.5).astype(int))
    precision = precision_score(y_test, (y_pred > 0.5).astype(int), average='weighted')
    recall = recall_score(y_test, (y_pred > 0.5).astype(int), average='weighted')
    accuracy_scores.append(accuracy)
    precision_scores.append(precision)
    recall_scores.append(recall)
    acc_scores.append(norm_accuracy(y_test, y_pred))
    acc_norm.append(calculate_accuracy(y_test, y_pred))

# Calculate the average accuracy across all folds
average_accuracy = sum(accuracy_scores) / len(accuracy_scores)
avg_precision = sum(precision_scores) / len(precision_scores)
avg_acc_norm = sum(acc_norm)/len(acc_norm)
avg_recall = sum(recall_scores) / len(recall_scores)
avg_acc = sum(acc_scores)/len(acc_scores)
f1 = 2 * (avg_precision * avg_recall) / (avg_precision + avg_recall)
grand_mean=(average_accuracy+avg_precision+avg_recall+f1+avg_acc_norm++avg_acc)/6
# Print the average accuracy
print("Average Accuracy: ", average_accuracy)
print("Accuracy: ", avg_acc)
print("Average Normalized Accuracy: ", avg_acc_norm)
print("Average Precision: ", avg_precision)
print("Average Recall: ", avg_recall)
print('F1 score:', f1)
print('Grand Mean:', grand_mean)
# Out:
# Epoch 1/15
# 48/48 [==============================] - 7s 64ms/step - loss: 0.7637 - accuracy: 0.3646 - val_loss: 0.3776 - val_accuracy: 0.5600 - lr: 0.0010
# Epoch 2/15
# 48/48 [==============================] - 1s 28ms/step - loss: 0.3360 - accuracy: 0.6354 - val_loss: 0.3733 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 3/15
# 48/48 [==============================] - 1s 29ms/step - loss: 0.2199 - accuracy: 0.8021 - val_loss: 0.3607 - val_accuracy: 0.6400 - lr: 0.0010
# Epoch 4/15
# 48/48 [==============================] - 1s 28ms/step - loss: 0.1345 - accuracy: 0.8958 - val_loss: 0.4314 - val_accuracy: 0.6400 - lr: 0.0010
# Epoch 5/15
# 48/48 [==============================] - 1s 28ms/step - loss: 0.0762 - accuracy: 0.9167 - val_loss: 0.5885 - val_accuracy: 0.5600 - lr: 0.0010
# Epoch 6/15
# 48/48 [==============================] - 1s 28ms/step - loss: 0.0590 - accuracy: 0.9688 - val_loss: 0.5246 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 7/15
# 47/48 [============================>.] - ETA: 0s - loss: 0.0230 - accuracy: 0.9681
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 48/48 [==============================] - 1s 29ms/step - loss: 0.0226 - accuracy: 0.9688 - val_loss: 0.7137 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 8/15
# 48/48 [==============================] - 2s 32ms/step - loss: 0.0054 - accuracy: 0.9792 - val_loss: 0.7634 - val_accuracy: 0.6000 - lr: 5.0000e-04
# Epoch 9/15
# 48/48 [==============================] - 2s 42ms/step - loss: 0.0023 - accuracy: 0.9688 - val_loss: 0.7954 - val_accuracy: 0.6000 - lr: 5.0000e-04
# Epoch 10/15
# 48/48 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9688Restoring model weights from the end of the best epoch: 3.
# 48/48 [==============================] - 2s 37ms/step - loss: 0.0015 - accuracy: 0.9688 - val_loss: 0.8089 - val_accuracy: 0.6000 - lr: 5.0000e-04
# Epoch 10: early stopping
# 1/1 [==============================] - 1s 628ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 6s 47ms/step - loss: 0.2857 - accuracy: 0.7010 - val_loss: 0.2116 - val_accuracy: 0.7917 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 1s 30ms/step - loss: 0.1588 - accuracy: 0.8557 - val_loss: 0.2038 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 2s 32ms/step - loss: 0.0855 - accuracy: 0.8969 - val_loss: 0.2240 - val_accuracy: 0.7917 - lr: 0.0010
# Epoch 4/15
# 49/49 [==============================] - 2s 44ms/step - loss: 0.0388 - accuracy: 0.9278 - val_loss: 0.2036 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 5/15
# 49/49 [==============================] - 2s 37ms/step - loss: 0.0184 - accuracy: 0.9588 - val_loss: 0.1795 - val_accuracy: 0.7917 - lr: 0.0010
# Epoch 6/15
# 49/49 [==============================] - ETA: 0s - loss: 0.0050 - accuracy: 0.9588
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 1s 30ms/step - loss: 0.0050 - accuracy: 0.9588 - val_loss: 0.1806 - val_accuracy: 0.7917 - lr: 0.0010
# Epoch 7/15
# 49/49 [==============================] - 1s 29ms/step - loss: 0.0058 - accuracy: 0.9588 - val_loss: 0.2062 - val_accuracy: 0.7500 - lr: 5.0000e-04
# Epoch 8/15
# 49/49 [==============================] - 1s 29ms/step - loss: 0.0020 - accuracy: 0.9691 - val_loss: 0.1992 - val_accuracy: 0.7500 - lr: 5.0000e-04
# Epoch 9/15
# 48/49 [============================>.] - ETA: 0s - loss: 0.0014 - accuracy: 0.9688Restoring model weights from the end of the best epoch: 2.
# 49/49 [==============================] - 2s 41ms/step - loss: 0.0015 - accuracy: 0.9691 - val_loss: 0.2002 - val_accuracy: 0.7917 - lr: 5.0000e-04
# Epoch 9: early stopping
# 1/1 [==============================] - 2s 2s/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 9s 50ms/step - loss: 0.1452 - accuracy: 0.8557 - val_loss: 0.0863 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 1s 29ms/step - loss: 0.0383 - accuracy: 0.9691 - val_loss: 0.0993 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0249 - accuracy: 0.9588 - val_loss: 0.0995 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 4/15
# 49/49 [==============================] - 2s 45ms/step - loss: 0.0064 - accuracy: 0.9897 - val_loss: 0.1422 - val_accuracy: 0.7917 - lr: 0.0010
# Epoch 5/15
# 48/49 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9792
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 3s 62ms/step - loss: 0.0011 - accuracy: 0.9794 - val_loss: 0.1456 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 6/15
# 49/49 [==============================] - 3s 59ms/step - loss: 4.4133e-04 - accuracy: 0.9794 - val_loss: 0.1508 - val_accuracy: 0.8333 - lr: 5.0000e-04
# Epoch 7/15
# 49/49 [==============================] - 2s 47ms/step - loss: 3.7262e-04 - accuracy: 0.9691 - val_loss: 0.1534 - val_accuracy: 0.8333 - lr: 5.0000e-04
# Epoch 8/15
# 49/49 [==============================] - ETA: 0s - loss: 3.2673e-04 - accuracy: 0.9794Restoring model weights from the end of the best epoch: 1.
# 49/49 [==============================] - 3s 54ms/step - loss: 3.2673e-04 - accuracy: 0.9794 - val_loss: 0.1591 - val_accuracy: 0.8333 - lr: 5.0000e-04
# Epoch 8: early stopping
# 1/1 [==============================] - 1s 988ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 8s 60ms/step - loss: 0.0917 - accuracy: 0.8866 - val_loss: 0.0190 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 1s 29ms/step - loss: 0.0347 - accuracy: 0.9588 - val_loss: 0.0117 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 1s 29ms/step - loss: 0.0177 - accuracy: 0.9381 - val_loss: 0.0145 - val_accuracy: 0.9167 - lr: 0.0010
# Epoch 4/15
# 49/49 [==============================] - 1s 29ms/step - loss: 0.0137 - accuracy: 0.9381 - val_loss: 0.0691 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 5/15
# 49/49 [==============================] - ETA: 0s - loss: 0.0346 - accuracy: 0.9381
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 1s 28ms/step - loss: 0.0346 - accuracy: 0.9381 - val_loss: 0.0249 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 6/15
# 49/49 [==============================] - 1s 29ms/step - loss: 0.0030 - accuracy: 0.9278 - val_loss: 0.0559 - val_accuracy: 0.9167 - lr: 5.0000e-04
# Epoch 7/15
# 49/49 [==============================] - 1s 29ms/step - loss: 4.2104e-04 - accuracy: 0.9381 - val_loss: 0.0534 - val_accuracy: 0.9167 - lr: 5.0000e-04
# Epoch 8/15
# 49/49 [==============================] - ETA: 0s - loss: 2.5324e-04 - accuracy: 0.9381Restoring model weights from the end of the best epoch: 1.
# 49/49 [==============================] - 3s 70ms/step - loss: 2.5324e-04 - accuracy: 0.9381 - val_loss: 0.0532 - val_accuracy: 0.9167 - lr: 5.0000e-04
# Epoch 8: early stopping
# 1/1 [==============================] - 1s 616ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 11s 118ms/step - loss: 0.0578 - accuracy: 0.9485 - val_loss: 0.0389 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0447 - accuracy: 0.9381 - val_loss: 0.0181 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 2s 43ms/step - loss: 0.0122 - accuracy: 0.9381 - val_loss: 0.1280 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 4/15
# 49/49 [==============================] - 2s 31ms/step - loss: 0.0233 - accuracy: 0.9588 - val_loss: 0.1332 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 5/15
# 48/49 [============================>.] - ETA: 0s - loss: 0.0414 - accuracy: 0.9479
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 1s 29ms/step - loss: 0.0410 - accuracy: 0.9381 - val_loss: 0.0809 - val_accuracy: 0.9167 - lr: 0.0010
# Epoch 6/15
# 49/49 [==============================] - 1s 29ms/step - loss: 0.0191 - accuracy: 0.9278 - val_loss: 0.0690 - val_accuracy: 0.9583 - lr: 5.0000e-04
# Epoch 7/15
# 49/49 [==============================] - 2s 34ms/step - loss: 0.0029 - accuracy: 0.9278 - val_loss: 0.0499 - val_accuracy: 0.9167 - lr: 5.0000e-04
# Epoch 8/15
# 48/49 [============================>.] - ETA: 0s - loss: 0.0023 - accuracy: 0.9375Restoring model weights from the end of the best epoch: 1.
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0022 - accuracy: 0.9381 - val_loss: 0.0493 - val_accuracy: 0.9167 - lr: 5.0000e-04
# Epoch 8: early stopping
# 1/1 [==============================] - 1s 633ms/step
# Average Accuracy:  0.812
# Accuracy:  0.9494666666666667
# Average Normalized Accuracy:  0.8370000000000001
# Average Precision:  0.8976205128205128
# Average Recall:  0.8515604395604395
# F1 score: 0.873984040834021
# Grand Mean: 0.8702719433136067
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.11.3)

# %%
import numpy as np
import xgboost as xgb
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, precision_score, recall_score

# Define the XGBoost classifier
model_xgb = xgb.XGBClassifier()

# Load your data and pr0.0.eprocess it
train_features = np.array(df['s2g_matrix_2g'].tolist())
train_labels = np.array(df[['envelope', 'lumen', 'plastoglobule', 'stroma', 'thylakoid_membrane']].values)

train_features = train_features.reshape(-1, 400)

# Initialize K-Fold cross-validator
kf = KFold(n_splits=5)

# Initialize a list to store accuracy scores
accuracy_scores = []
precision_scores = []
recall_scores = []

# Iterate over each sample for LOOCV
for train_index, test_index in kf.split(train_features):
    X_train, X_test = train_features[train_index], train_features[test_index]
    y_train, y_test = train_labels[train_index], train_labels[test_index]

    # Fit the XGBoost model to the training data
    model_xgb.fit(X_train, y_train)

    # Make predictions on the current test sample
    y_pred = model_xgb.predict(X_test)

    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')
    accuracy_scores.append(accuracy)
    precision_scores.append(precision)
    recall_scores.append(recall)
    acc_scores.append(norm_accuracy(y_test, y_pred))
    acc_norm.append(calculate_accuracy(y_test, y_pred))

# Calculate the average accuracy across all folds
average_accuracy = sum(accuracy_scores) / len(accuracy_scores)
avg_precision = sum(precision_scores) / len(precision_scores)
avg_acc_norm = sum(acc_norm)/len(acc_norm)
avg_recall = sum(recall_scores) / len(recall_scores)
avg_acc = sum(acc_scores)/len(acc_scores)
f1 = 2 * (avg_precision * avg_recall) / (avg_precision + avg_recall)
grand_mean=(average_accuracy+avg_precision+avg_recall+f1+avg_acc_norm++avg_acc)/6
# Print the average accuracy
print("Average Accuracy: ", average_accuracy)
print("Accuracy: ", avg_acc)
print("Average Normalized Accuracy: ", avg_acc_norm)
print("Average Precision: ", avg_precision)
print("Average Recall: ", avg_recall)
print('F1 score:', f1)
print('Grand Mean:', grand_mean)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Average Accuracy:  0.35466666666666663
# Accuracy:  0.8762666666666667
# Average Normalized Accuracy:  0.6198333333333333
# Average Precision:  0.5212334537257614
# Average Recall:  0.43758241758241756
# F1 score: 0.47575890560710665
# Grand Mean: 0.5475569072636587
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import KFold

# Define the k-NN classifier
model_knn = KNeighborsClassifier(n_neighbors=5)  # You can adjust the number of neighbors (k) as needed

# Load your data and preprocess it
train_features = np.array(df['s2g_matrix_2g'].tolist())
train_labels = np.array(df[['envelope', 'lumen', 'plastoglobule', 'stroma', 'thylakoid_membrane']].values)

train_features = train_features.reshape(-1, 400)

# Initialize K-Fold cross-validator
kf = KFold(n_splits=5)

# Initialize a list to store accuracy scores
accuracy_scores = []
precision_scores = []
recall_scores = []
acc_scores = []
acc_norm = []

# Iterate over each sample for LOOCV
for train_index, test_index in kf.split(train_features):
    X_train, X_test = train_features[train_index], train_features[test_index]
    y_train, y_test = train_labels[train_index], train_labels[test_index]

    # Fit the k-NN model to the training data
    model_knn.fit(X_train, y_train)

    # Make predictions on the current test sample
    y_pred = model_knn.predict(X_test)

    # Calculate and store the accuracy for this fold
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')
    accuracy_scores.append(accuracy)
    precision_scores.append(precision)
    recall_scores.append(recall)
    acc_scores.append(norm_accuracy(y_test, y_pred))
    acc_norm.append(calculate_accuracy(y_test, y_pred))

# Calculate the average accuracy across all folds
average_accuracy = sum(accuracy_scores) / len(accuracy_scores)
avg_precision = sum(precision_scores) / len(precision_scores)
avg_acc_norm = sum(acc_norm)/len(acc_norm)
avg_recall = sum(recall_scores) / len(recall_scores)
avg_acc = sum(acc_scores)/len(acc_scores)
f1 = 2 * (avg_precision * avg_recall) / (avg_precision + avg_recall)
grand_mean=(average_accuracy+avg_precision+avg_recall+f1+avg_acc_norm++avg_acc)/6
# Print the average accuracy
print("Average Accuracy: ", average_accuracy)
print("Accuracy: ", avg_acc)
print("Average Normalized Accuracy: ", avg_acc_norm)
print("Average Precision: ", avg_precision)
print("Average Recall: ", avg_recall)
print('F1 score:', f1)
print('Grand Mean:', grand_mean)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Average Accuracy:  0.41233333333333333
# Accuracy:  0.8112666666666668
# Average Normalized Accuracy:  0.4538333333333333
# Average Precision:  0.5830928679163974
# Average Recall:  0.46035164835164827
# F1 score: 0.5145031838347374
# Grand Mean: 0.5392301722393528
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# **Bi-gram+S3G Matrix Model**

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import KFold
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau

# Define the model
model_s3g = keras.Sequential([
    keras.layers.Input(shape=(None, 400)),
    keras.layers.Dense(400, activation='relu',kernel_initializer='he_normal'),
    keras.layers.Dense(100, activation='relu',kernel_initializer='he_normal'),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(25, activation='relu',kernel_initializer='he_normal'),
    keras.layers.Dense(5, activation='sigmoid')
])

# Load your data and preprocess it
train_features = np.array(df['s3g_matrix_2g'].tolist())
train_labels = np.array(df[['envelope', 'lumen', 'plastoglobule', 'stroma', 'thylakoid_membrane']].values)

train_features = train_features.reshape(-1, 400)

# Initialize K-Fold cross-validator
kf = KFold(n_splits=5)

# Initialize a list to store accuracy scores
accuracy_scores = []
precision_scores = []
recall_scores = []
acc_scores = []
acc_norm = []

# Iterate over each sample for LOOCV
for train_index, test_index in kf.split(train_features):
    X_train, X_test = train_features[train_index], train_features[test_index]
    y_train, y_test = train_labels[train_index], train_labels[test_index]

    # Compile the model and set up callbacks (as in your code)
    model_s3g.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    early_stopping = EarlyStopping(monitor='val_accuracy', min_delta=0.00005, patience=5, verbose=1, restore_best_weights=True)
    lr_scheduler = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=3, min_lr=1e-6, verbose=1)
    callbacks = [early_stopping, lr_scheduler]

    batch_size = 2
    model_s3g.fit(X_train, y_train, epochs=15, validation_data=(X_test, y_test), batch_size=batch_size, callbacks=callbacks)

    # Make predictions on the current test sample
    y_pred = model_s3g.predict(X_test)


    # Calculate and store the accuracy for this fold
    accuracy = accuracy_score(y_test, (y_pred > 0.5).astype(int))
    precision = precision_score(y_test, (y_pred > 0.5).astype(int), average='weighted')
    recall = recall_score(y_test, (y_pred > 0.5).astype(int), average='weighted')
    accuracy_scores.append(accuracy)
    precision_scores.append(precision)
    recall_scores.append(recall)
    acc_scores.append(norm_accuracy(y_test, y_pred))
    acc_norm.append(calculate_accuracy(y_test, y_pred))

# Calculate the average accuracy across all folds
average_accuracy = sum(accuracy_scores) / len(accuracy_scores)
avg_precision = sum(precision_scores) / len(precision_scores)
avg_acc_norm = sum(acc_norm)/len(acc_norm)
avg_recall = sum(recall_scores) / len(recall_scores)
avg_acc = sum(acc_scores)/len(acc_scores)
f1 = 2 * (avg_precision * avg_recall) / (avg_precision + avg_recall)
grand_mean=(average_accuracy+avg_precision+avg_recall+f1+avg_acc_norm++avg_acc)/6
# Print the average accuracy
print("Average Accuracy: ", average_accuracy)
print("Accuracy: ", avg_acc)
print("Average Normalized Accuracy: ", avg_acc_norm)
print("Average Precision: ", avg_precision)
print("Average Recall: ", avg_recall)
print('F1 score:', f1)
print('Grand Mean:', grand_mean)
# Out:
# Epoch 1/15
# 48/48 [==============================] - 1s 9ms/step - loss: 0.5084 - accuracy: 0.4375 - val_loss: 0.4448 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 2/15
# 48/48 [==============================] - 0s 5ms/step - loss: 0.2238 - accuracy: 0.7708 - val_loss: 0.3537 - val_accuracy: 0.6800 - lr: 0.0010
# Epoch 3/15
# 48/48 [==============================] - 0s 5ms/step - loss: 0.1513 - accuracy: 0.8750 - val_loss: 0.3648 - val_accuracy: 0.6400 - lr: 0.0010
# Epoch 4/15
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0841 - accuracy: 0.8958 - val_loss: 0.4789 - val_accuracy: 0.5600 - lr: 0.0010
# Epoch 5/15
# 48/48 [==============================] - ETA: 0s - loss: 0.0818 - accuracy: 0.9062
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0818 - accuracy: 0.9062 - val_loss: 0.4353 - val_accuracy: 0.6400 - lr: 0.0010
# Epoch 6/15
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0463 - accuracy: 0.9271 - val_loss: 0.4493 - val_accuracy: 0.6400 - lr: 5.0000e-04
# Epoch 7/15
# 41/48 [========================>.....] - ETA: 0s - loss: 0.0290 - accuracy: 0.9268Restoring model weights from the end of the best epoch: 2.
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0327 - accuracy: 0.9271 - val_loss: 0.4928 - val_accuracy: 0.6400 - lr: 5.0000e-04
# Epoch 7: early stopping
# 1/1 [==============================] - 0s 99ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 2s 14ms/step - loss: 0.2308 - accuracy: 0.7732 - val_loss: 0.1084 - val_accuracy: 0.9167 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 8ms/step - loss: 0.1234 - accuracy: 0.8660 - val_loss: 0.0903 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0677 - accuracy: 0.8969 - val_loss: 0.0847 - val_accuracy: 0.9167 - lr: 0.0010
# Epoch 4/15
# 43/49 [=========================>....] - ETA: 0s - loss: 0.0467 - accuracy: 0.9535
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0426 - accuracy: 0.9588 - val_loss: 0.0952 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 5/15
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0347 - accuracy: 0.9381 - val_loss: 0.1083 - val_accuracy: 0.8750 - lr: 5.0000e-04
# Epoch 6/15
# 49/49 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 0.9588Restoring model weights from the end of the best epoch: 1.
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0161 - accuracy: 0.9588 - val_loss: 0.1035 - val_accuracy: 0.9167 - lr: 5.0000e-04
# Epoch 6: early stopping
# 1/1 [==============================] - 0s 65ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 1s 8ms/step - loss: 0.1403 - accuracy: 0.9072 - val_loss: 0.0728 - val_accuracy: 0.9167 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0699 - accuracy: 0.9381 - val_loss: 0.0762 - val_accuracy: 0.9167 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0345 - accuracy: 0.9794 - val_loss: 0.0901 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 4/15
# 40/49 [=======================>......] - ETA: 0s - loss: 0.0272 - accuracy: 0.9500
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0249 - accuracy: 0.9588 - val_loss: 0.0780 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 5/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0195 - accuracy: 0.9588 - val_loss: 0.1507 - val_accuracy: 0.8333 - lr: 5.0000e-04
# Epoch 6/15
# 39/49 [======================>.......] - ETA: 0s - loss: 0.0103 - accuracy: 0.9359Restoring model weights from the end of the best epoch: 1.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0105 - accuracy: 0.9381 - val_loss: 0.1188 - val_accuracy: 0.8333 - lr: 5.0000e-04
# Epoch 6: early stopping
# 1/1 [==============================] - 0s 66ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 2s 8ms/step - loss: 0.0836 - accuracy: 0.9278 - val_loss: 0.0308 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0711 - accuracy: 0.9381 - val_loss: 0.0281 - val_accuracy: 0.9167 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0477 - accuracy: 0.9381 - val_loss: 0.0256 - val_accuracy: 0.9167 - lr: 0.0010
# Epoch 4/15
# 39/49 [======================>.......] - ETA: 0s - loss: 0.0316 - accuracy: 0.9359
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0359 - accuracy: 0.9278 - val_loss: 0.0233 - val_accuracy: 0.9167 - lr: 0.0010
# Epoch 5/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0145 - accuracy: 0.9485 - val_loss: 0.0216 - val_accuracy: 0.9583 - lr: 5.0000e-04
# Epoch 6/15
# 45/49 [==========================>...] - ETA: 0s - loss: 0.0067 - accuracy: 0.9333Restoring model weights from the end of the best epoch: 1.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0066 - accuracy: 0.9381 - val_loss: 0.0138 - val_accuracy: 0.9583 - lr: 5.0000e-04
# Epoch 6: early stopping
# 1/1 [==============================] - 0s 78ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 2s 14ms/step - loss: 0.1020 - accuracy: 0.9175 - val_loss: 0.0232 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0549 - accuracy: 0.9175 - val_loss: 0.0398 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0326 - accuracy: 0.9485 - val_loss: 0.0468 - val_accuracy: 0.9167 - lr: 0.0010
# Epoch 4/15
# 45/49 [==========================>...] - ETA: 0s - loss: 0.0179 - accuracy: 0.9556
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0168 - accuracy: 0.9485 - val_loss: 0.0584 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 5/15
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0147 - accuracy: 0.9485 - val_loss: 0.0496 - val_accuracy: 0.9167 - lr: 5.0000e-04
# Epoch 6/15
# 49/49 [==============================] - ETA: 0s - loss: 0.0102 - accuracy: 0.9794Restoring model weights from the end of the best epoch: 1.
# 49/49 [==============================] - 1s 24ms/step - loss: 0.0102 - accuracy: 0.9794 - val_loss: 0.0541 - val_accuracy: 0.9167 - lr: 5.0000e-04
# Epoch 6: early stopping
# 1/1 [==============================] - 0s 64ms/step
# Average Accuracy:  0.8373333333333335
# Accuracy:  0.9546000000000001
# Average Normalized Accuracy:  0.8623333333333333
# Average Precision:  0.8994871794871795
# Average Recall:  0.8446593406593408
# F1 score: 0.8712114941964234
# Grand Mean: 0.8782707801682684
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# **Bi-gram+S4G Matrix Model**

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import KFold
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau

# Define the model
model_s4g = keras.Sequential([
    keras.layers.Input(shape=(None, 400)),
    keras.layers.Dense(400, activation='relu',kernel_initializer='he_normal'),
    keras.layers.Dense(100, activation='relu',kernel_initializer='he_normal'),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(25, activation='relu',kernel_initializer='he_normal'),
    keras.layers.Dense(5, activation='sigmoid')
])

# Load your data and preprocess it
train_features = np.array(df['s4g_matrix_2g'].tolist())
train_labels = np.array(df[['envelope', 'lumen', 'plastoglobule', 'stroma', 'thylakoid_membrane']].values)

train_features = train_features.reshape(-1, 400)

# Initialize K-Fold cross-validator
kf = KFold(n_splits=5)

# Initialize a list to store accuracy scores
accuracy_scores = []
precision_scores = []
recall_scores = []
acc_scores = []
acc_norm = []

# Iterate over each sample for LOOCV
for train_index, test_index in kf.split(train_features):
    X_train, X_test = train_features[train_index], train_features[test_index]
    y_train, y_test = train_labels[train_index], train_labels[test_index]

    # Compile the model and set up callbacks (as in your code)
    model_s4g.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    early_stopping = EarlyStopping(monitor='val_accuracy', min_delta=0.00005, patience=5, verbose=1, restore_best_weights=True)
    lr_scheduler = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=3, min_lr=1e-6, verbose=1)
    callbacks = [early_stopping, lr_scheduler]

    batch_size = 2
    model_s4g.fit(X_train, y_train, epochs=15, validation_data=(X_test, y_test), batch_size=batch_size, callbacks=callbacks)

    # Make predictions on the current test sample
    y_pred = model_s4g.predict(X_test)


    # Calculate and store the accuracy for this fold
    accuracy = accuracy_score(y_test, (y_pred > 0.5).astype(int))
    precision = precision_score(y_test, (y_pred > 0.5).astype(int), average='weighted')
    recall = recall_score(y_test, (y_pred > 0.5).astype(int), average='weighted')
    accuracy_scores.append(accuracy)
    precision_scores.append(precision)
    recall_scores.append(recall)
    acc_scores.append(norm_accuracy(y_test, y_pred))
    acc_norm.append(calculate_accuracy(y_test, y_pred))

# Calculate the average accuracy across all folds
average_accuracy = sum(accuracy_scores) / len(accuracy_scores)
avg_precision = sum(precision_scores) / len(precision_scores)
avg_acc_norm = sum(acc_norm)/len(acc_norm)
avg_recall = sum(recall_scores) / len(recall_scores)
avg_acc = sum(acc_scores)/len(acc_scores)
f1 = 2 * (avg_precision * avg_recall) / (avg_precision + avg_recall)
grand_mean=(average_accuracy+avg_precision+avg_recall+f1+avg_acc_norm++avg_acc)/6
# Print the average accuracy
print("Average Accuracy: ", average_accuracy)
print("Accuracy: ", avg_acc)
print("Average Normalized Accuracy: ", avg_acc_norm)
print("Average Precision: ", avg_precision)
print("Average Recall: ", avg_recall)
print('F1 score:', f1)
print('Grand Mean:', grand_mean)
# Out:
# Epoch 1/15
# 48/48 [==============================] - 1s 8ms/step - loss: 0.4909 - accuracy: 0.3958 - val_loss: 0.4027 - val_accuracy: 0.5600 - lr: 0.0010
# Epoch 2/15
# 48/48 [==============================] - 0s 5ms/step - loss: 0.2780 - accuracy: 0.7396 - val_loss: 0.3869 - val_accuracy: 0.5200 - lr: 0.0010
# Epoch 3/15
# 48/48 [==============================] - 0s 6ms/step - loss: 0.1598 - accuracy: 0.8542 - val_loss: 0.3929 - val_accuracy: 0.5600 - lr: 0.0010
# Epoch 4/15
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0973 - accuracy: 0.8854 - val_loss: 0.4354 - val_accuracy: 0.6400 - lr: 0.0010
# Epoch 5/15
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0708 - accuracy: 0.9271 - val_loss: 0.4526 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 6/15
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0496 - accuracy: 0.9271 - val_loss: 0.4804 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 7/15
# 39/48 [=======================>......] - ETA: 0s - loss: 0.0424 - accuracy: 0.9231
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0432 - accuracy: 0.9271 - val_loss: 0.4729 - val_accuracy: 0.6400 - lr: 0.0010
# Epoch 8/15
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0273 - accuracy: 0.9271 - val_loss: 0.4861 - val_accuracy: 0.6400 - lr: 5.0000e-04
# Epoch 9/15
# 42/48 [=========================>....] - ETA: 0s - loss: 0.0207 - accuracy: 0.9762Restoring model weights from the end of the best epoch: 4.
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0304 - accuracy: 0.9688 - val_loss: 0.5024 - val_accuracy: 0.6000 - lr: 5.0000e-04
# Epoch 9: early stopping
# 1/1 [==============================] - 0s 69ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 1s 8ms/step - loss: 0.1858 - accuracy: 0.8454 - val_loss: 0.0450 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0808 - accuracy: 0.9381 - val_loss: 0.0468 - val_accuracy: 0.9167 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0409 - accuracy: 0.9072 - val_loss: 0.0444 - val_accuracy: 0.9167 - lr: 0.0010
# Epoch 4/15
# 45/49 [==========================>...] - ETA: 0s - loss: 0.0303 - accuracy: 0.9556
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0304 - accuracy: 0.9485 - val_loss: 0.0927 - val_accuracy: 0.9167 - lr: 0.0010
# Epoch 5/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0223 - accuracy: 0.9588 - val_loss: 0.0748 - val_accuracy: 0.9167 - lr: 5.0000e-04
# Epoch 6/15
# 42/49 [========================>.....] - ETA: 0s - loss: 0.0180 - accuracy: 0.9643Restoring model weights from the end of the best epoch: 1.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0158 - accuracy: 0.9588 - val_loss: 0.0769 - val_accuracy: 0.9167 - lr: 5.0000e-04
# Epoch 6: early stopping
# 1/1 [==============================] - 0s 66ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 1s 8ms/step - loss: 0.1173 - accuracy: 0.8866 - val_loss: 0.0232 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0408 - accuracy: 0.9278 - val_loss: 0.0276 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0379 - accuracy: 0.9485 - val_loss: 0.0285 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 4/15
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0225 - accuracy: 0.9794 - val_loss: 0.0442 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 5/15
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0187 - accuracy: 0.9691 - val_loss: 0.0319 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 6/15
# 45/49 [==========================>...] - ETA: 0s - loss: 0.0115 - accuracy: 0.9778
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0108 - accuracy: 0.9794 - val_loss: 0.0499 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 7/15
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0051 - accuracy: 0.9897 - val_loss: 0.0358 - val_accuracy: 0.9167 - lr: 5.0000e-04
# Epoch 8/15
# 45/49 [==========================>...] - ETA: 0s - loss: 0.0073 - accuracy: 0.9444Restoring model weights from the end of the best epoch: 3.
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0069 - accuracy: 0.9485 - val_loss: 0.0300 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 8: early stopping
# 1/1 [==============================] - 0s 65ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 1s 8ms/step - loss: 0.0478 - accuracy: 0.9485 - val_loss: 0.0071 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0483 - accuracy: 0.9175 - val_loss: 0.0058 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0269 - accuracy: 0.9485 - val_loss: 0.0020 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 4/15
# 42/49 [========================>.....] - ETA: 0s - loss: 0.0134 - accuracy: 0.9643
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0129 - accuracy: 0.9691 - val_loss: 0.0014 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 5/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0062 - accuracy: 0.9485 - val_loss: 0.0015 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 6/15
# 39/49 [======================>.......] - ETA: 0s - loss: 0.0087 - accuracy: 0.9359Restoring model weights from the end of the best epoch: 1.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0075 - accuracy: 0.9381 - val_loss: 0.0029 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 6: early stopping
# 1/1 [==============================] - 0s 73ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 1s 8ms/step - loss: 0.0336 - accuracy: 0.9485 - val_loss: 0.0201 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0134 - accuracy: 0.9794 - val_loss: 0.0463 - val_accuracy: 0.9167 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0171 - accuracy: 0.9691 - val_loss: 0.0243 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 4/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0095 - accuracy: 0.9485 - val_loss: 0.0060 - val_accuracy: 0.9167 - lr: 0.0010
# Epoch 5/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0131 - accuracy: 0.9381 - val_loss: 0.0194 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 6/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0209 - accuracy: 0.9278 - val_loss: 0.0209 - val_accuracy: 0.9167 - lr: 0.0010
# Epoch 7/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0113 - accuracy: 0.9278 - val_loss: 0.0474 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 8/15
# 44/49 [=========================>....] - ETA: 0s - loss: 0.0058 - accuracy: 0.9432
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0053 - accuracy: 0.9485 - val_loss: 0.0224 - val_accuracy: 0.9167 - lr: 0.0010
# Epoch 9/15
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0010 - accuracy: 0.9381 - val_loss: 0.0344 - val_accuracy: 0.8750 - lr: 5.0000e-04
# Epoch 10/15
# 48/49 [============================>.] - ETA: 0s - loss: 0.0032 - accuracy: 0.9375Restoring model weights from the end of the best epoch: 5.
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0031 - accuracy: 0.9381 - val_loss: 0.0217 - val_accuracy: 0.9167 - lr: 5.0000e-04
# Epoch 10: early stopping
# 1/1 [==============================] - 0s 100ms/step
# Average Accuracy:  0.9036666666666667
# Accuracy:  0.9679333333333334
# Average Normalized Accuracy:  0.9118333333333333
# Average Precision:  0.886646153846154
# Average Recall:  0.9199999999999999
# F1 score: 0.9030151917705567
# Grand Mean: 0.9155157798250073
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# **Tri-gram+S0G Matrix Model**

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import KFold
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau

# Define the model
model_s0g_3g = keras.Sequential([
    keras.layers.Input(shape=(None, 400)),
    keras.layers.Dense(400, activation='relu',kernel_initializer='he_normal'),
    keras.layers.Dense(100, activation='relu',kernel_initializer='he_normal'),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(25, activation='relu',kernel_initializer='he_normal'),
    keras.layers.Dense(5, activation='sigmoid')
])

# Load your data and preprocess it
train_features = np.array(df['s0g_matrix_3gram'].tolist())
train_labels = np.array(df[['envelope', 'lumen', 'plastoglobule', 'stroma', 'thylakoid_membrane']].values)

train_features = train_features.reshape(-1, 400)

# Initialize K-Fold cross-validator
kf = KFold(n_splits=5)

# Initialize a list to store accuracy scores
accuracy_scores = []
precision_scores = []
recall_scores = []
acc_scores = []
acc_norm = []

# Iterate over each sample for LOOCV
for train_index, test_index in kf.split(train_features):
    X_train, X_test = train_features[train_index], train_features[test_index]
    y_train, y_test = train_labels[train_index], train_labels[test_index]

    # Compile the model and set up callbacks (as in your code)
    model_s0g_3g.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    early_stopping = EarlyStopping(monitor='val_accuracy', min_delta=0.00005, patience=5, verbose=1, restore_best_weights=True)
    lr_scheduler = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=3, min_lr=1e-6, verbose=1)
    callbacks = [early_stopping, lr_scheduler]

    batch_size = 2
    model_s0g_3g.fit(X_train, y_train, epochs=15, validation_data=(X_test, y_test), batch_size=batch_size, callbacks=callbacks)

    # Make predictions on the current test sample
    y_pred = model_s0g_3g.predict(X_test)


    # Calculate and store the accuracy for this fold
    accuracy = accuracy_score(y_test, (y_pred > 0.5).astype(int))
    precision = precision_score(y_test, (y_pred > 0.5).astype(int), average='weighted')
    recall = recall_score(y_test, (y_pred > 0.5).astype(int), average='weighted')
    accuracy_scores.append(accuracy)
    precision_scores.append(precision)
    recall_scores.append(recall)
    acc_scores.append(norm_accuracy(y_test, y_pred))
    acc_norm.append(calculate_accuracy(y_test, y_pred))

# Calculate the average accuracy across all folds
average_accuracy = sum(accuracy_scores) / len(accuracy_scores)
avg_precision = sum(precision_scores) / len(precision_scores)
avg_acc_norm = sum(acc_norm)/len(acc_norm)
avg_recall = sum(recall_scores) / len(recall_scores)
avg_acc = sum(acc_scores)/len(acc_scores)
f1 = 2 * (avg_precision * avg_recall) / (avg_precision + avg_recall)
grand_mean=(average_accuracy+avg_precision+avg_recall+f1+avg_acc_norm++avg_acc)/6
# Print the average accuracy
print("Average Accuracy: ", average_accuracy)
print("Accuracy: ", avg_acc)
print("Average Normalized Accuracy: ", avg_acc_norm)
print("Average Precision: ", avg_precision)
print("Average Recall: ", avg_recall)
print('F1 score:', f1)
print('Grand Mean:', grand_mean)
# Out:
# Epoch 1/15
# 48/48 [==============================] - 2s 15ms/step - loss: 0.5194 - accuracy: 0.3854 - val_loss: 0.4041 - val_accuracy: 0.6400 - lr: 0.0010
# Epoch 2/15
# 48/48 [==============================] - 0s 9ms/step - loss: 0.4259 - accuracy: 0.4583 - val_loss: 0.4335 - val_accuracy: 0.2400 - lr: 0.0010
# Epoch 3/15
# 48/48 [==============================] - 0s 10ms/step - loss: 0.4269 - accuracy: 0.4688 - val_loss: 0.3973 - val_accuracy: 0.6400 - lr: 0.0010
# Epoch 4/15
# 43/48 [=========================>....] - ETA: 0s - loss: 0.4153 - accuracy: 0.4302
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 48/48 [==============================] - 0s 10ms/step - loss: 0.4204 - accuracy: 0.4062 - val_loss: 0.4103 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 5/15
# 48/48 [==============================] - 0s 10ms/step - loss: 0.4052 - accuracy: 0.4896 - val_loss: 0.3766 - val_accuracy: 0.5600 - lr: 5.0000e-04
# Epoch 6/15
# 40/48 [========================>.....] - ETA: 0s - loss: 0.4066 - accuracy: 0.4500Restoring model weights from the end of the best epoch: 1.
# 48/48 [==============================] - 0s 9ms/step - loss: 0.3953 - accuracy: 0.4896 - val_loss: 0.3817 - val_accuracy: 0.6400 - lr: 5.0000e-04
# Epoch 6: early stopping
# 1/1 [==============================] - 0s 66ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 1s 9ms/step - loss: 0.4586 - accuracy: 0.3918 - val_loss: 0.3700 - val_accuracy: 0.6250 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 6ms/step - loss: 0.4570 - accuracy: 0.4639 - val_loss: 0.3725 - val_accuracy: 0.6250 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 6ms/step - loss: 0.4258 - accuracy: 0.4845 - val_loss: 0.3881 - val_accuracy: 0.7083 - lr: 0.0010
# Epoch 4/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.4304 - accuracy: 0.4330 - val_loss: 0.3522 - val_accuracy: 0.7083 - lr: 0.0010
# Epoch 5/15
# 49/49 [==============================] - 0s 6ms/step - loss: 0.4367 - accuracy: 0.4845 - val_loss: 0.3424 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 6/15
# 48/49 [============================>.] - ETA: 0s - loss: 0.3983 - accuracy: 0.4896
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.4024 - accuracy: 0.4845 - val_loss: 0.3520 - val_accuracy: 0.6250 - lr: 0.0010
# Epoch 7/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.3987 - accuracy: 0.5361 - val_loss: 0.3334 - val_accuracy: 0.6667 - lr: 5.0000e-04
# Epoch 8/15
# 43/49 [=========================>....] - ETA: 0s - loss: 0.3895 - accuracy: 0.4535Restoring model weights from the end of the best epoch: 3.
# 49/49 [==============================] - 0s 6ms/step - loss: 0.3873 - accuracy: 0.4433 - val_loss: 0.3355 - val_accuracy: 0.6667 - lr: 5.0000e-04
# Epoch 8: early stopping
# 1/1 [==============================] - 0s 70ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 1s 8ms/step - loss: 0.4389 - accuracy: 0.4639 - val_loss: 0.3869 - val_accuracy: 0.5833 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.4152 - accuracy: 0.4845 - val_loss: 0.3772 - val_accuracy: 0.5833 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 6ms/step - loss: 0.4149 - accuracy: 0.4021 - val_loss: 0.3627 - val_accuracy: 0.6250 - lr: 0.0010
# Epoch 4/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.3975 - accuracy: 0.5567 - val_loss: 0.3701 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 5/15
# 49/49 [==============================] - 0s 6ms/step - loss: 0.4032 - accuracy: 0.4948 - val_loss: 0.3572 - val_accuracy: 0.5833 - lr: 0.0010
# Epoch 6/15
# 47/49 [===========================>..] - ETA: 0s - loss: 0.3881 - accuracy: 0.4681
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 6ms/step - loss: 0.3887 - accuracy: 0.4742 - val_loss: 0.3897 - val_accuracy: 0.5417 - lr: 0.0010
# Epoch 7/15
# 49/49 [==============================] - 0s 6ms/step - loss: 0.3637 - accuracy: 0.5773 - val_loss: 0.3663 - val_accuracy: 0.6250 - lr: 5.0000e-04
# Epoch 8/15
# 44/49 [=========================>....] - ETA: 0s - loss: 0.3920 - accuracy: 0.5000Restoring model weights from the end of the best epoch: 3.
# 49/49 [==============================] - 0s 6ms/step - loss: 0.3902 - accuracy: 0.5052 - val_loss: 0.3622 - val_accuracy: 0.5833 - lr: 5.0000e-04
# Epoch 8: early stopping
# 1/1 [==============================] - 0s 77ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 1s 9ms/step - loss: 0.4062 - accuracy: 0.5052 - val_loss: 0.3678 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.3944 - accuracy: 0.5155 - val_loss: 0.3692 - val_accuracy: 0.4167 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 6ms/step - loss: 0.3832 - accuracy: 0.5567 - val_loss: 0.3781 - val_accuracy: 0.3750 - lr: 0.0010
# Epoch 4/15
# 47/49 [===========================>..] - ETA: 0s - loss: 0.3837 - accuracy: 0.5000
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 6ms/step - loss: 0.3850 - accuracy: 0.5052 - val_loss: 0.3730 - val_accuracy: 0.4167 - lr: 0.0010
# Epoch 5/15
# 49/49 [==============================] - 0s 8ms/step - loss: 0.3565 - accuracy: 0.5464 - val_loss: 0.4006 - val_accuracy: 0.4583 - lr: 5.0000e-04
# Epoch 6/15
# 44/49 [=========================>....] - ETA: 0s - loss: 0.3692 - accuracy: 0.5568Restoring model weights from the end of the best epoch: 1.
# 49/49 [==============================] - 0s 10ms/step - loss: 0.3697 - accuracy: 0.5567 - val_loss: 0.3821 - val_accuracy: 0.4167 - lr: 5.0000e-04
# Epoch 6: early stopping
# 1/1 [==============================] - 0s 96ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 2s 15ms/step - loss: 0.3742 - accuracy: 0.6289 - val_loss: 0.4177 - val_accuracy: 0.4167 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 10ms/step - loss: 0.3932 - accuracy: 0.5361 - val_loss: 0.5355 - val_accuracy: 0.2917 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.3678 - accuracy: 0.5567 - val_loss: 0.4549 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 4/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.3619 - accuracy: 0.5361 - val_loss: 0.4542 - val_accuracy: 0.4583 - lr: 0.0010
# Epoch 5/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.3705 - accuracy: 0.5258 - val_loss: 0.4532 - val_accuracy: 0.3750 - lr: 0.0010
# Epoch 6/15
# 46/49 [===========================>..] - ETA: 0s - loss: 0.3586 - accuracy: 0.5652
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 6ms/step - loss: 0.3490 - accuracy: 0.5773 - val_loss: 0.4655 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 7/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.3467 - accuracy: 0.5361 - val_loss: 0.4445 - val_accuracy: 0.5417 - lr: 5.0000e-04
# Epoch 8/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.3498 - accuracy: 0.5464 - val_loss: 0.4469 - val_accuracy: 0.5000 - lr: 5.0000e-04
# Epoch 9/15
# 49/49 [==============================] - 0s 6ms/step - loss: 0.3362 - accuracy: 0.6186 - val_loss: 0.4414 - val_accuracy: 0.5417 - lr: 5.0000e-04
# Epoch 10/15
# 44/49 [=========================>....] - ETA: 0s - loss: 0.3311 - accuracy: 0.5909
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 49/49 [==============================] - 0s 6ms/step - loss: 0.3283 - accuracy: 0.5876 - val_loss: 0.4554 - val_accuracy: 0.5000 - lr: 5.0000e-04
# Epoch 11/15
# 49/49 [==============================] - 0s 6ms/step - loss: 0.3390 - accuracy: 0.5155 - val_loss: 0.4541 - val_accuracy: 0.5000 - lr: 2.5000e-04
# Epoch 12/15
# 47/49 [===========================>..] - ETA: 0s - loss: 0.3291 - accuracy: 0.5957Restoring model weights from the end of the best epoch: 7.
# 49/49 [==============================] - 0s 6ms/step - loss: 0.3238 - accuracy: 0.6082 - val_loss: 0.4511 - val_accuracy: 0.5000 - lr: 2.5000e-04
# Epoch 12: early stopping
# 1/1 [==============================] - 0s 73ms/step
# Average Accuracy:  0.2966666666666667
# Accuracy:  0.8196000000000001
# Average Normalized Accuracy:  0.3008333333333334
# Average Precision:  0.4008957708957709
# Average Recall:  0.2832967032967033
# F1 score: 0.33198976762907983
# Grand Mean: 0.40554704030359234
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# **Tri-gram+S1G Matrix Model**

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import KFold
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau

# Define the model
model_s1g_3g = keras.Sequential([
    keras.layers.Input(shape=(None, 400)),
    keras.layers.Dense(400, activation='relu',kernel_initializer='he_normal'),
    keras.layers.Dense(100, activation='relu',kernel_initializer='he_normal'),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(25, activation='relu',kernel_initializer='he_normal'),
    keras.layers.Dense(5, activation='sigmoid')
])

# Load your data and preprocess it
train_features = np.array(df['s1g_matrix_3gram'].tolist())
train_labels = np.array(df[['envelope', 'lumen', 'plastoglobule', 'stroma', 'thylakoid_membrane']].values)

train_features = train_features.reshape(-1, 400)

# Initialize K-Fold cross-validator
kf = KFold(n_splits=5)

# Initialize a list to store accuracy scores
accuracy_scores = []
precision_scores = []
recall_scores = []
acc_scores = []
acc_norm = []

# Iterate over each sample for LOOCV
for train_index, test_index in kf.split(train_features):
    X_train, X_test = train_features[train_index], train_features[test_index]
    y_train, y_test = train_labels[train_index], train_labels[test_index]

    # Compile the model and set up callbacks (as in your code)
    model_s1g_3g.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    early_stopping = EarlyStopping(monitor='val_accuracy', min_delta=0.00005, patience=5, verbose=1, restore_best_weights=True)
    lr_scheduler = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=3, min_lr=1e-6, verbose=1)
    callbacks = [early_stopping, lr_scheduler]

    batch_size = 2
    model_s1g_3g.fit(X_train, y_train, epochs=15, validation_data=(X_test, y_test), batch_size=batch_size, callbacks=callbacks)

    # Make predictions on the current test sample
    y_pred = model_s1g_3g.predict(X_test)


    # Calculate and store the accuracy for this fold
    accuracy = accuracy_score(y_test, (y_pred > 0.5).astype(int))
    precision = precision_score(y_test, (y_pred > 0.5).astype(int), average='weighted')
    recall = recall_score(y_test, (y_pred > 0.5).astype(int), average='weighted')
    accuracy_scores.append(accuracy)
    precision_scores.append(precision)
    recall_scores.append(recall)
    acc_scores.append(norm_accuracy(y_test, y_pred))
    acc_norm.append(calculate_accuracy(y_test, y_pred))

# Calculate the average accuracy across all folds
average_accuracy = sum(accuracy_scores) / len(accuracy_scores)
avg_precision = sum(precision_scores) / len(precision_scores)
avg_acc_norm = sum(acc_norm)/len(acc_norm)
avg_recall = sum(recall_scores) / len(recall_scores)
avg_acc = sum(acc_scores)/len(acc_scores)
f1 = 2 * (avg_precision * avg_recall) / (avg_precision + avg_recall)
grand_mean=(average_accuracy+avg_precision+avg_recall+f1+avg_acc_norm++avg_acc)/6
# Print the average accuracy
print("Average Accuracy: ", average_accuracy)
print("Accuracy: ", avg_acc)
print("Average Normalized Accuracy: ", avg_acc_norm)
print("Average Precision: ", avg_precision)
print("Average Recall: ", avg_recall)
print('F1 score:', f1)
print('Grand Mean:', grand_mean)
# Out:
# Epoch 1/15
# 48/48 [==============================] - 1s 10ms/step - loss: 0.5614 - accuracy: 0.2917 - val_loss: 0.4841 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 2/15
# 48/48 [==============================] - 0s 5ms/step - loss: 0.4456 - accuracy: 0.4062 - val_loss: 0.4215 - val_accuracy: 0.5600 - lr: 0.0010
# Epoch 3/15
# 48/48 [==============================] - 0s 5ms/step - loss: 0.4205 - accuracy: 0.4688 - val_loss: 0.4066 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 4/15
# 48/48 [==============================] - 0s 5ms/step - loss: 0.4307 - accuracy: 0.4167 - val_loss: 0.4141 - val_accuracy: 0.5600 - lr: 0.0010
# Epoch 5/15
# 48/48 [==============================] - 0s 5ms/step - loss: 0.4160 - accuracy: 0.5000 - val_loss: 0.4095 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 6/15
# 39/48 [=======================>......] - ETA: 0s - loss: 0.4201 - accuracy: 0.4872
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4155 - accuracy: 0.4792 - val_loss: 0.4170 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 7/15
# 48/48 [==============================] - 0s 5ms/step - loss: 0.3827 - accuracy: 0.5625 - val_loss: 0.3894 - val_accuracy: 0.6000 - lr: 5.0000e-04
# Epoch 8/15
# 46/48 [===========================>..] - ETA: 0s - loss: 0.3876 - accuracy: 0.5326Restoring model weights from the end of the best epoch: 3.
# 48/48 [==============================] - 0s 6ms/step - loss: 0.3911 - accuracy: 0.5208 - val_loss: 0.3632 - val_accuracy: 0.6000 - lr: 5.0000e-04
# Epoch 8: early stopping
# 1/1 [==============================] - 0s 74ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 1s 8ms/step - loss: 0.4451 - accuracy: 0.4124 - val_loss: 0.3749 - val_accuracy: 0.6250 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.4102 - accuracy: 0.5361 - val_loss: 0.4012 - val_accuracy: 0.5417 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.4108 - accuracy: 0.4639 - val_loss: 0.3412 - val_accuracy: 0.6250 - lr: 0.0010
# Epoch 4/15
# 49/49 [==============================] - 0s 6ms/step - loss: 0.4148 - accuracy: 0.5155 - val_loss: 0.3451 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 5/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.4056 - accuracy: 0.4536 - val_loss: 0.3183 - val_accuracy: 0.6250 - lr: 0.0010
# Epoch 6/15
# 49/49 [==============================] - 0s 6ms/step - loss: 0.3905 - accuracy: 0.5052 - val_loss: 0.3750 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 7/15
# 39/49 [======================>.......] - ETA: 0s - loss: 0.3772 - accuracy: 0.5000
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.3845 - accuracy: 0.5258 - val_loss: 0.3330 - val_accuracy: 0.5833 - lr: 0.0010
# Epoch 8/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.3916 - accuracy: 0.4639 - val_loss: 0.3301 - val_accuracy: 0.6667 - lr: 5.0000e-04
# Epoch 9/15
# 49/49 [==============================] - ETA: 0s - loss: 0.3820 - accuracy: 0.5052Restoring model weights from the end of the best epoch: 4.
# 49/49 [==============================] - 0s 7ms/step - loss: 0.3820 - accuracy: 0.5052 - val_loss: 0.3265 - val_accuracy: 0.6250 - lr: 5.0000e-04
# Epoch 9: early stopping
# 1/1 [==============================] - 0s 70ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 1s 8ms/step - loss: 0.4058 - accuracy: 0.4948 - val_loss: 0.3566 - val_accuracy: 0.5833 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 6ms/step - loss: 0.3864 - accuracy: 0.5052 - val_loss: 0.3477 - val_accuracy: 0.5833 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.3700 - accuracy: 0.5361 - val_loss: 0.3793 - val_accuracy: 0.5833 - lr: 0.0010
# Epoch 4/15
# 37/49 [=====================>........] - ETA: 0s - loss: 0.3972 - accuracy: 0.5000
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.3861 - accuracy: 0.4742 - val_loss: 0.3864 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 5/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.3716 - accuracy: 0.4742 - val_loss: 0.3490 - val_accuracy: 0.5833 - lr: 5.0000e-04
# Epoch 6/15
# 42/49 [========================>.....] - ETA: 0s - loss: 0.3646 - accuracy: 0.5000Restoring model weights from the end of the best epoch: 1.
# 49/49 [==============================] - 0s 6ms/step - loss: 0.3626 - accuracy: 0.5258 - val_loss: 0.3534 - val_accuracy: 0.5833 - lr: 5.0000e-04
# Epoch 6: early stopping
# 1/1 [==============================] - 0s 73ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 1s 8ms/step - loss: 0.3989 - accuracy: 0.5670 - val_loss: 0.3650 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.3973 - accuracy: 0.4948 - val_loss: 0.3753 - val_accuracy: 0.4167 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.3547 - accuracy: 0.5773 - val_loss: 0.3742 - val_accuracy: 0.4167 - lr: 0.0010
# Epoch 4/15
# 37/49 [=====================>........] - ETA: 0s - loss: 0.3652 - accuracy: 0.5270
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.3771 - accuracy: 0.5052 - val_loss: 0.3892 - val_accuracy: 0.3750 - lr: 0.0010
# Epoch 5/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.3560 - accuracy: 0.5464 - val_loss: 0.3680 - val_accuracy: 0.3750 - lr: 5.0000e-04
# Epoch 6/15
# 45/49 [==========================>...] - ETA: 0s - loss: 0.3476 - accuracy: 0.5889Restoring model weights from the end of the best epoch: 1.
# 49/49 [==============================] - 0s 6ms/step - loss: 0.3447 - accuracy: 0.5876 - val_loss: 0.3717 - val_accuracy: 0.3750 - lr: 5.0000e-04
# Epoch 6: early stopping
# 1/1 [==============================] - 0s 85ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 1s 8ms/step - loss: 0.3860 - accuracy: 0.5567 - val_loss: 0.4450 - val_accuracy: 0.2917 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.3628 - accuracy: 0.5361 - val_loss: 0.4242 - val_accuracy: 0.4167 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.3643 - accuracy: 0.5464 - val_loss: 0.4799 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 4/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.3583 - accuracy: 0.5361 - val_loss: 0.4577 - val_accuracy: 0.3750 - lr: 0.0010
# Epoch 5/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.3696 - accuracy: 0.5155 - val_loss: 0.4260 - val_accuracy: 0.4583 - lr: 0.0010
# Epoch 6/15
# 49/49 [==============================] - 0s 9ms/step - loss: 0.3441 - accuracy: 0.5567 - val_loss: 0.4346 - val_accuracy: 0.4583 - lr: 0.0010
# Epoch 7/15
# 49/49 [==============================] - 0s 10ms/step - loss: 0.3358 - accuracy: 0.5876 - val_loss: 0.4548 - val_accuracy: 0.4167 - lr: 0.0010
# Epoch 8/15
# 44/49 [=========================>....] - ETA: 0s - loss: 0.3177 - accuracy: 0.5341
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 10ms/step - loss: 0.3170 - accuracy: 0.5464 - val_loss: 0.5376 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 9/15
# 49/49 [==============================] - 0s 9ms/step - loss: 0.3226 - accuracy: 0.5567 - val_loss: 0.4273 - val_accuracy: 0.4583 - lr: 5.0000e-04
# Epoch 10/15
# 49/49 [==============================] - 0s 9ms/step - loss: 0.3180 - accuracy: 0.5464 - val_loss: 0.4180 - val_accuracy: 0.5000 - lr: 5.0000e-04
# Epoch 11/15
# 49/49 [==============================] - 0s 10ms/step - loss: 0.2998 - accuracy: 0.6186 - val_loss: 0.4062 - val_accuracy: 0.5000 - lr: 5.0000e-04
# Epoch 12/15
# 49/49 [==============================] - 0s 9ms/step - loss: 0.3073 - accuracy: 0.6186 - val_loss: 0.4420 - val_accuracy: 0.4583 - lr: 5.0000e-04
# Epoch 13/15
# 44/49 [=========================>....] - ETA: 0s - loss: 0.3114 - accuracy: 0.5682
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 49/49 [==============================] - 0s 9ms/step - loss: 0.3087 - accuracy: 0.5876 - val_loss: 0.4389 - val_accuracy: 0.4167 - lr: 5.0000e-04
# Epoch 14/15
# 49/49 [==============================] - 0s 9ms/step - loss: 0.2798 - accuracy: 0.6186 - val_loss: 0.4679 - val_accuracy: 0.3750 - lr: 2.5000e-04
# Epoch 15/15
# 42/49 [========================>.....] - ETA: 0s - loss: 0.2796 - accuracy: 0.5952Restoring model weights from the end of the best epoch: 10.
# 49/49 [==============================] - 0s 8ms/step - loss: 0.2897 - accuracy: 0.5979 - val_loss: 0.4724 - val_accuracy: 0.4167 - lr: 2.5000e-04
# Epoch 15: early stopping
# 1/1 [==============================] - 0s 67ms/step
# Average Accuracy:  0.29933333333333334
# Accuracy:  0.8182000000000003
# Average Normalized Accuracy:  0.3243333333333333
# Average Precision:  0.5308278388278389
# Average Recall:  0.31654945054945055
# F1 score: 0.3965960920212695
# Grand Mean: 0.44764000801087095
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# **Tri-gram+S2G Matrix Model**

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import KFold
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau

# Define the model
model_s2g_3g = keras.Sequential([
    keras.layers.Input(shape=(None, 400)),
    keras.layers.Dense(400, activation='relu',kernel_initializer='he_normal'),
    keras.layers.Dense(100, activation='relu',kernel_initializer='he_normal'),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(25, activation='relu',kernel_initializer='he_normal'),
    keras.layers.Dense(5, activation='sigmoid')
])

# Load your data and preprocess it
train_features = np.array(df['s2g_matrix_3gram'].tolist())
train_labels = np.array(df[['envelope', 'lumen', 'plastoglobule', 'stroma', 'thylakoid_membrane']].values)

train_features = train_features.reshape(-1, 400)

# Initialize K-Fold cross-validator
kf = KFold(n_splits=5)

# Initialize a list to store accuracy scores
accuracy_scores = []
precision_scores = []
recall_scores = []
acc_scores = []
acc_norm = []

# Iterate over each sample for LOOCV
for train_index, test_index in kf.split(train_features):
    X_train, X_test = train_features[train_index], train_features[test_index]
    y_train, y_test = train_labels[train_index], train_labels[test_index]

    # Compile the model and set up callbacks (as in your code)
    model_s2g_3g.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    early_stopping = EarlyStopping(monitor='val_accuracy', min_delta=0.00005, patience=5, verbose=1, restore_best_weights=True)
    lr_scheduler = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=3, min_lr=1e-6, verbose=1)
    callbacks = [early_stopping, lr_scheduler]

    batch_size = 2
    model_s2g_3g.fit(X_train, y_train, epochs=15, validation_data=(X_test, y_test), batch_size=batch_size, callbacks=callbacks)

    # Make predictions on the current test sample
    y_pred = model_s2g_3g.predict(X_test)


    # Calculate and store the accuracy for this fold
    accuracy = accuracy_score(y_test, (y_pred > 0.5).astype(int))
    precision = precision_score(y_test, (y_pred > 0.5).astype(int), average='weighted')
    recall = recall_score(y_test, (y_pred > 0.5).astype(int), average='weighted')
    accuracy_scores.append(accuracy)
    precision_scores.append(precision)
    recall_scores.append(recall)
    acc_scores.append(norm_accuracy(y_test, y_pred))
    acc_norm.append(calculate_accuracy(y_test, y_pred))

# Calculate the average accuracy across all folds
average_accuracy = sum(accuracy_scores) / len(accuracy_scores)
avg_precision = sum(precision_scores) / len(precision_scores)
avg_acc_norm = sum(acc_norm)/len(acc_norm)
avg_recall = sum(recall_scores) / len(recall_scores)
avg_acc = sum(acc_scores)/len(acc_scores)
f1 = 2 * (avg_precision * avg_recall) / (avg_precision + avg_recall)
grand_mean=(average_accuracy+avg_precision+avg_recall+f1+avg_acc_norm++avg_acc)/6
# Print the average accuracy
print("Average Accuracy: ", average_accuracy)
print("Accuracy: ", avg_acc)
print("Average Normalized Accuracy: ", avg_acc_norm)
print("Average Precision: ", avg_precision)
print("Average Recall: ", avg_recall)
print('F1 score:', f1)
print('Grand Mean:', grand_mean)
# Out:
# Epoch 1/15
# 48/48 [==============================] - 1s 8ms/step - loss: 0.5872 - accuracy: 0.3333 - val_loss: 0.4759 - val_accuracy: 0.2000 - lr: 0.0010
# Epoch 2/15
# 48/48 [==============================] - 0s 5ms/step - loss: 0.4859 - accuracy: 0.4479 - val_loss: 0.3916 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 3/15
# 48/48 [==============================] - 0s 5ms/step - loss: 0.4180 - accuracy: 0.5312 - val_loss: 0.3846 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 4/15
# 48/48 [==============================] - 0s 5ms/step - loss: 0.4122 - accuracy: 0.4688 - val_loss: 0.3974 - val_accuracy: 0.5600 - lr: 0.0010
# Epoch 5/15
# 39/48 [=======================>......] - ETA: 0s - loss: 0.4144 - accuracy: 0.5256
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 48/48 [==============================] - 0s 5ms/step - loss: 0.4122 - accuracy: 0.5208 - val_loss: 0.3704 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 6/15
# 48/48 [==============================] - 0s 5ms/step - loss: 0.3822 - accuracy: 0.5729 - val_loss: 0.3704 - val_accuracy: 0.6000 - lr: 5.0000e-04
# Epoch 7/15
# 39/48 [=======================>......] - ETA: 0s - loss: 0.3862 - accuracy: 0.5128Restoring model weights from the end of the best epoch: 2.
# 48/48 [==============================] - 0s 5ms/step - loss: 0.3756 - accuracy: 0.5312 - val_loss: 0.3654 - val_accuracy: 0.6000 - lr: 5.0000e-04
# Epoch 7: early stopping
# 1/1 [==============================] - 0s 68ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 1s 8ms/step - loss: 0.4559 - accuracy: 0.4639 - val_loss: 0.3599 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.4348 - accuracy: 0.4639 - val_loss: 0.3803 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 6ms/step - loss: 0.4273 - accuracy: 0.4639 - val_loss: 0.3758 - val_accuracy: 0.6250 - lr: 0.0010
# Epoch 4/15
# 40/49 [=======================>......] - ETA: 0s - loss: 0.4128 - accuracy: 0.5750
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.4177 - accuracy: 0.5258 - val_loss: 0.3784 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 5/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.3916 - accuracy: 0.5361 - val_loss: 0.3548 - val_accuracy: 0.7083 - lr: 5.0000e-04
# Epoch 6/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.3927 - accuracy: 0.5361 - val_loss: 0.3494 - val_accuracy: 0.6667 - lr: 5.0000e-04
# Epoch 7/15
# 49/49 [==============================] - 0s 6ms/step - loss: 0.3921 - accuracy: 0.5464 - val_loss: 0.3361 - val_accuracy: 0.6667 - lr: 5.0000e-04
# Epoch 8/15
# 37/49 [=====================>........] - ETA: 0s - loss: 0.4121 - accuracy: 0.3919
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.3998 - accuracy: 0.4124 - val_loss: 0.3307 - val_accuracy: 0.6250 - lr: 5.0000e-04
# Epoch 9/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.3665 - accuracy: 0.5773 - val_loss: 0.3335 - val_accuracy: 0.6667 - lr: 2.5000e-04
# Epoch 10/15
# 41/49 [========================>.....] - ETA: 0s - loss: 0.3912 - accuracy: 0.4878Restoring model weights from the end of the best epoch: 5.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.3792 - accuracy: 0.4948 - val_loss: 0.3265 - val_accuracy: 0.6250 - lr: 2.5000e-04
# Epoch 10: early stopping
# 1/1 [==============================] - 0s 69ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 1s 8ms/step - loss: 0.3937 - accuracy: 0.4948 - val_loss: 0.3391 - val_accuracy: 0.5417 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.4016 - accuracy: 0.4845 - val_loss: 0.3369 - val_accuracy: 0.5833 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.3976 - accuracy: 0.5155 - val_loss: 0.3295 - val_accuracy: 0.5833 - lr: 0.0010
# Epoch 4/15
# 49/49 [==============================] - 0s 6ms/step - loss: 0.3832 - accuracy: 0.5155 - val_loss: 0.3318 - val_accuracy: 0.6250 - lr: 0.0010
# Epoch 5/15
# 49/49 [==============================] - 0s 9ms/step - loss: 0.3750 - accuracy: 0.5464 - val_loss: 0.3325 - val_accuracy: 0.5833 - lr: 0.0010
# Epoch 6/15
# 49/49 [==============================] - 0s 9ms/step - loss: 0.3669 - accuracy: 0.5361 - val_loss: 0.3343 - val_accuracy: 0.5833 - lr: 0.0010
# Epoch 7/15
# 47/49 [===========================>..] - ETA: 0s - loss: 0.3624 - accuracy: 0.5106
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 8ms/step - loss: 0.3636 - accuracy: 0.5155 - val_loss: 0.3452 - val_accuracy: 0.5833 - lr: 0.0010
# Epoch 8/15
# 49/49 [==============================] - 0s 9ms/step - loss: 0.3557 - accuracy: 0.5052 - val_loss: 0.3302 - val_accuracy: 0.5833 - lr: 5.0000e-04
# Epoch 9/15
# 44/49 [=========================>....] - ETA: 0s - loss: 0.3501 - accuracy: 0.5795Restoring model weights from the end of the best epoch: 4.
# 49/49 [==============================] - 0s 9ms/step - loss: 0.3573 - accuracy: 0.5670 - val_loss: 0.3247 - val_accuracy: 0.6250 - lr: 5.0000e-04
# Epoch 9: early stopping
# 1/1 [==============================] - 0s 64ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 1s 8ms/step - loss: 0.3792 - accuracy: 0.5567 - val_loss: 0.3690 - val_accuracy: 0.5417 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.3757 - accuracy: 0.5567 - val_loss: 0.4282 - val_accuracy: 0.3750 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 6ms/step - loss: 0.3605 - accuracy: 0.5155 - val_loss: 0.4001 - val_accuracy: 0.4167 - lr: 0.0010
# Epoch 4/15
# 48/49 [============================>.] - ETA: 0s - loss: 0.3557 - accuracy: 0.5729
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 6ms/step - loss: 0.3581 - accuracy: 0.5670 - val_loss: 0.3969 - val_accuracy: 0.4167 - lr: 0.0010
# Epoch 5/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.3394 - accuracy: 0.6186 - val_loss: 0.3817 - val_accuracy: 0.4167 - lr: 5.0000e-04
# Epoch 6/15
# 48/49 [============================>.] - ETA: 0s - loss: 0.3345 - accuracy: 0.5833Restoring model weights from the end of the best epoch: 1.
# 49/49 [==============================] - 0s 6ms/step - loss: 0.3344 - accuracy: 0.5876 - val_loss: 0.3948 - val_accuracy: 0.4583 - lr: 5.0000e-04
# Epoch 6: early stopping
# 1/1 [==============================] - 0s 68ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 1s 8ms/step - loss: 0.3603 - accuracy: 0.5567 - val_loss: 0.4749 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 6ms/step - loss: 0.3378 - accuracy: 0.5773 - val_loss: 0.3935 - val_accuracy: 0.5417 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.3425 - accuracy: 0.5567 - val_loss: 0.4098 - val_accuracy: 0.4583 - lr: 0.0010
# Epoch 4/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.3223 - accuracy: 0.5464 - val_loss: 0.4150 - val_accuracy: 0.4583 - lr: 0.0010
# Epoch 5/15
# 38/49 [======================>.......] - ETA: 0s - loss: 0.3166 - accuracy: 0.6184
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.3309 - accuracy: 0.5876 - val_loss: 0.3987 - val_accuracy: 0.4583 - lr: 0.0010
# Epoch 6/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.3349 - accuracy: 0.5567 - val_loss: 0.4169 - val_accuracy: 0.4583 - lr: 5.0000e-04
# Epoch 7/15
# 40/49 [=======================>......] - ETA: 0s - loss: 0.3219 - accuracy: 0.6125Restoring model weights from the end of the best epoch: 2.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.3195 - accuracy: 0.6082 - val_loss: 0.4224 - val_accuracy: 0.4583 - lr: 5.0000e-04
# Epoch 7: early stopping
# 1/1 [==============================] - 0s 69ms/step
# Average Accuracy:  0.4366666666666667
# Accuracy:  0.8246666666666668
# Average Normalized Accuracy:  0.4491666666666666
# Average Precision:  0.5287125410821063
# Average Recall:  0.4287912087912088
# F1 score: 0.47353817595735387
# Grand Mean: 0.5235903209717782
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# **4-gram on S0G Matrix Model**

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import KFold
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau

# Define the model
model_s0g_4g = keras.Sequential([
    keras.layers.Input(shape=(None, 400)),
    keras.layers.Dense(400, activation='relu',kernel_initializer='he_normal'),
    keras.layers.Dense(100, activation='relu',kernel_initializer='he_normal'),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(25, activation='relu',kernel_initializer='he_normal'),
    keras.layers.Dense(5, activation='sigmoid')
])

# Load your data and preprocess it
train_features = np.array(df['s0g_matrix_4gram'].tolist())
train_labels = np.array(df[['envelope', 'lumen', 'plastoglobule', 'stroma', 'thylakoid_membrane']].values)

train_features = train_features.reshape(-1, 400)

# Initialize K-Fold cross-validator
kf = KFold(n_splits=5)

# Initialize a list to store accuracy scores
accuracy_scores = []
precision_scores = []
recall_scores = []
acc_scores = []
acc_norm = []

# Iterate over each sample for LOOCV
for train_index, test_index in kf.split(train_features):
    X_train, X_test = train_features[train_index], train_features[test_index]
    y_train, y_test = train_labels[train_index], train_labels[test_index]

    # Compile the model and set up callbacks (as in your code)
    model_s0g_4g.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    early_stopping = EarlyStopping(monitor='val_accuracy', min_delta=0.00005, patience=5, verbose=1, restore_best_weights=True)
    lr_scheduler = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=3, min_lr=1e-6, verbose=1)
    callbacks = [early_stopping, lr_scheduler]

    batch_size = 2
    model_s0g_4g.fit(X_train, y_train, epochs=15, validation_data=(X_test, y_test), batch_size=batch_size, callbacks=callbacks)

    # Make predictions on the current test sample
    y_pred = model_s0g_4g.predict(X_test)


    # Calculate and store the accuracy for this fold
    accuracy = accuracy_score(y_test, (y_pred > 0.5).astype(int))
    precision = precision_score(y_test, (y_pred > 0.5).astype(int), average='weighted')
    recall = recall_score(y_test, (y_pred > 0.5).astype(int), average='weighted')
    accuracy_scores.append(accuracy)
    precision_scores.append(precision)
    recall_scores.append(recall)
    acc_scores.append(norm_accuracy(y_test, y_pred))
    acc_norm.append(calculate_accuracy(y_test, y_pred))

# Calculate the average accuracy across all folds
average_accuracy = sum(accuracy_scores) / len(accuracy_scores)
avg_precision = sum(precision_scores) / len(precision_scores)
avg_acc_norm = sum(acc_norm)/len(acc_norm)
avg_recall = sum(recall_scores) / len(recall_scores)
avg_acc = sum(acc_scores)/len(acc_scores)
f1 = 2 * (avg_precision * avg_recall) / (avg_precision + avg_recall)
grand_mean=(average_accuracy+avg_precision+avg_recall+f1+avg_acc_norm++avg_acc)/6
# Print the average accuracy
print("Average Accuracy: ", average_accuracy)
print("Accuracy: ", avg_acc)
print("Average Normalized Accuracy: ", avg_acc_norm)
print("Average Precision: ", avg_precision)
print("Average Recall: ", avg_recall)
print('F1 score:', f1)
print('Grand Mean:', grand_mean)
# Out:
# Epoch 1/15
# 48/48 [==============================] - 1s 8ms/step - loss: 0.7149 - accuracy: 0.1562 - val_loss: 0.5841 - val_accuracy: 0.4400 - lr: 0.0010
# Epoch 2/15
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5432 - accuracy: 0.4375 - val_loss: 0.4989 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 3/15
# 48/48 [==============================] - 0s 5ms/step - loss: 0.4542 - accuracy: 0.5729 - val_loss: 0.4272 - val_accuracy: 0.5200 - lr: 0.0010
# Epoch 4/15
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4058 - accuracy: 0.5417 - val_loss: 0.4661 - val_accuracy: 0.3600 - lr: 0.0010
# Epoch 5/15
# 48/48 [==============================] - 0s 6ms/step - loss: 0.3434 - accuracy: 0.5938 - val_loss: 0.4137 - val_accuracy: 0.5200 - lr: 0.0010
# Epoch 6/15
# 42/48 [=========================>....] - ETA: 0s - loss: 0.3153 - accuracy: 0.6548
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 48/48 [==============================] - 0s 7ms/step - loss: 0.3083 - accuracy: 0.6667 - val_loss: 0.4126 - val_accuracy: 0.5200 - lr: 0.0010
# Epoch 7/15
# 48/48 [==============================] - 0s 9ms/step - loss: 0.2601 - accuracy: 0.7292 - val_loss: 0.4482 - val_accuracy: 0.3600 - lr: 5.0000e-04
# Epoch 8/15
# 48/48 [==============================] - 0s 10ms/step - loss: 0.2573 - accuracy: 0.6875 - val_loss: 0.4374 - val_accuracy: 0.5600 - lr: 5.0000e-04
# Epoch 9/15
# 48/48 [==============================] - 0s 9ms/step - loss: 0.2555 - accuracy: 0.6979 - val_loss: 0.4532 - val_accuracy: 0.5600 - lr: 5.0000e-04
# Epoch 10/15
# 48/48 [==============================] - 0s 10ms/step - loss: 0.2450 - accuracy: 0.6562 - val_loss: 0.4415 - val_accuracy: 0.4800 - lr: 5.0000e-04
# Epoch 11/15
# 48/48 [==============================] - ETA: 0s - loss: 0.2086 - accuracy: 0.7292
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 48/48 [==============================] - 0s 9ms/step - loss: 0.2086 - accuracy: 0.7292 - val_loss: 0.4611 - val_accuracy: 0.4000 - lr: 5.0000e-04
# Epoch 12/15
# 48/48 [==============================] - 0s 9ms/step - loss: 0.2062 - accuracy: 0.7500 - val_loss: 0.4693 - val_accuracy: 0.3600 - lr: 2.5000e-04
# Epoch 13/15
# 43/48 [=========================>....] - ETA: 0s - loss: 0.1999 - accuracy: 0.7442Restoring model weights from the end of the best epoch: 8.
# 48/48 [==============================] - 0s 10ms/step - loss: 0.2032 - accuracy: 0.7292 - val_loss: 0.4738 - val_accuracy: 0.3600 - lr: 2.5000e-04
# Epoch 13: early stopping
# 1/1 [==============================] - 0s 101ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 2s 9ms/step - loss: 0.3417 - accuracy: 0.6082 - val_loss: 0.2367 - val_accuracy: 0.7917 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.3029 - accuracy: 0.6082 - val_loss: 0.2407 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.2646 - accuracy: 0.6598 - val_loss: 0.2170 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 4/15
# 46/49 [===========================>..] - ETA: 0s - loss: 0.2473 - accuracy: 0.6957
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 6ms/step - loss: 0.2422 - accuracy: 0.7010 - val_loss: 0.2522 - val_accuracy: 0.7083 - lr: 0.0010
# Epoch 5/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.2510 - accuracy: 0.7216 - val_loss: 0.2527 - val_accuracy: 0.7500 - lr: 5.0000e-04
# Epoch 6/15
# 40/49 [=======================>......] - ETA: 0s - loss: 0.2111 - accuracy: 0.7500Restoring model weights from the end of the best epoch: 1.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.2083 - accuracy: 0.7423 - val_loss: 0.2783 - val_accuracy: 0.5833 - lr: 5.0000e-04
# Epoch 6: early stopping
# 1/1 [==============================] - 0s 68ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 1s 9ms/step - loss: 0.3356 - accuracy: 0.5670 - val_loss: 0.2395 - val_accuracy: 0.9167 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.2666 - accuracy: 0.6701 - val_loss: 0.2555 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.2696 - accuracy: 0.6392 - val_loss: 0.3582 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 4/15
# 41/49 [========================>.....] - ETA: 0s - loss: 0.2347 - accuracy: 0.6829
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.2341 - accuracy: 0.6907 - val_loss: 0.3479 - val_accuracy: 0.5833 - lr: 0.0010
# Epoch 5/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.2317 - accuracy: 0.7113 - val_loss: 0.3363 - val_accuracy: 0.6250 - lr: 5.0000e-04
# Epoch 6/15
# 36/49 [=====================>........] - ETA: 0s - loss: 0.1841 - accuracy: 0.7361Restoring model weights from the end of the best epoch: 1.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.2129 - accuracy: 0.7010 - val_loss: 0.3586 - val_accuracy: 0.8333 - lr: 5.0000e-04
# Epoch 6: early stopping
# 1/1 [==============================] - 0s 69ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 1s 8ms/step - loss: 0.3089 - accuracy: 0.5979 - val_loss: 0.2292 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.2400 - accuracy: 0.7216 - val_loss: 0.2141 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.2904 - accuracy: 0.7010 - val_loss: 0.2054 - val_accuracy: 0.7083 - lr: 0.0010
# Epoch 4/15
# 40/49 [=======================>......] - ETA: 0s - loss: 0.2386 - accuracy: 0.7500
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.2351 - accuracy: 0.7629 - val_loss: 0.2061 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 5/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.2081 - accuracy: 0.7732 - val_loss: 0.2298 - val_accuracy: 0.7917 - lr: 5.0000e-04
# Epoch 6/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.2001 - accuracy: 0.8041 - val_loss: 0.1926 - val_accuracy: 0.8333 - lr: 5.0000e-04
# Epoch 7/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1915 - accuracy: 0.7526 - val_loss: 0.2140 - val_accuracy: 0.6667 - lr: 5.0000e-04
# Epoch 8/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1844 - accuracy: 0.7732 - val_loss: 0.1910 - val_accuracy: 0.7917 - lr: 5.0000e-04
# Epoch 9/15
# 40/49 [=======================>......] - ETA: 0s - loss: 0.1750 - accuracy: 0.8125
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1812 - accuracy: 0.7938 - val_loss: 0.1822 - val_accuracy: 0.7500 - lr: 5.0000e-04
# Epoch 10/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1754 - accuracy: 0.7835 - val_loss: 0.1866 - val_accuracy: 0.7500 - lr: 2.5000e-04
# Epoch 11/15
# 39/49 [======================>.......] - ETA: 0s - loss: 0.1336 - accuracy: 0.8333Restoring model weights from the end of the best epoch: 6.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1590 - accuracy: 0.8144 - val_loss: 0.1790 - val_accuracy: 0.7083 - lr: 2.5000e-04
# Epoch 11: early stopping
# 1/1 [==============================] - 0s 96ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 1s 8ms/step - loss: 0.2455 - accuracy: 0.7732 - val_loss: 0.2343 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.2273 - accuracy: 0.7835 - val_loss: 0.1938 - val_accuracy: 0.7083 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.2215 - accuracy: 0.7423 - val_loss: 0.2337 - val_accuracy: 0.7917 - lr: 0.0010
# Epoch 4/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.2186 - accuracy: 0.7526 - val_loss: 0.2545 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 5/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.2032 - accuracy: 0.7938 - val_loss: 0.2453 - val_accuracy: 0.7083 - lr: 0.0010
# Epoch 6/15
# 41/49 [========================>.....] - ETA: 0s - loss: 0.1706 - accuracy: 0.8415
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1806 - accuracy: 0.8247 - val_loss: 0.2297 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 7/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1583 - accuracy: 0.8247 - val_loss: 0.3064 - val_accuracy: 0.6667 - lr: 5.0000e-04
# Epoch 8/15
# 39/49 [======================>.......] - ETA: 0s - loss: 0.1510 - accuracy: 0.8077Restoring model weights from the end of the best epoch: 3.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1452 - accuracy: 0.8144 - val_loss: 0.2273 - val_accuracy: 0.7917 - lr: 5.0000e-04
# Epoch 8: early stopping
# 1/1 [==============================] - 0s 70ms/step
# Average Accuracy:  0.6546666666666667
# Accuracy:  0.8816666666666668
# Average Normalized Accuracy:  0.6755
# Average Precision:  0.7518360267183796
# Average Recall:  0.6396483516483518
# F1 score: 0.6912196538846255
# Grand Mean: 0.7157562275974484
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# **4-gram on S1G Matrix Model**

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import KFold
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau

# Define the model
model_s1g_4g = keras.Sequential([
    keras.layers.Input(shape=(None, 400)),
    keras.layers.Dense(400, activation='relu',kernel_initializer='he_normal'),
    keras.layers.Dense(100, activation='relu',kernel_initializer='he_normal'),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(25, activation='relu',kernel_initializer='he_normal'),
    keras.layers.Dense(5, activation='sigmoid')
])

# Load your data and preprocess it
train_features = np.array(df['s1g_matrix_4gram'].tolist())
train_labels = np.array(df[['envelope', 'lumen', 'plastoglobule', 'stroma', 'thylakoid_membrane']].values)

train_features = train_features.reshape(-1, 400)

# Initialize K-Fold cross-validator
kf = KFold(n_splits=5)

# Initialize a list to store accuracy scores
accuracy_scores = []
precision_scores = []
recall_scores = []
acc_scores = []
acc_norm = []

# Iterate over each sample for LOOCV
for train_index, test_index in kf.split(train_features):
    X_train, X_test = train_features[train_index], train_features[test_index]
    y_train, y_test = train_labels[train_index], train_labels[test_index]

    # Compile the model and set up callbacks (as in your code)
    model_s1g_4g.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    early_stopping = EarlyStopping(monitor='val_accuracy', min_delta=0.00005, patience=5, verbose=1, restore_best_weights=True)
    lr_scheduler = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=3, min_lr=1e-6, verbose=1)
    callbacks = [early_stopping, lr_scheduler]

    batch_size = 2
    model_s1g_4g.fit(X_train, y_train, epochs=15, validation_data=(X_test, y_test), batch_size=batch_size, callbacks=callbacks)

    # Make predictions on the current test sample
    y_pred = model_s1g_4g.predict(X_test)


    # Calculate and store the accuracy for this fold
    accuracy = accuracy_score(y_test, (y_pred > 0.5).astype(int))
    precision = precision_score(y_test, (y_pred > 0.5).astype(int), average='weighted')
    recall = recall_score(y_test, (y_pred > 0.5).astype(int), average='weighted')
    accuracy_scores.append(accuracy)
    precision_scores.append(precision)
    recall_scores.append(recall)
    acc_scores.append(norm_accuracy(y_test, y_pred))
    acc_norm.append(calculate_accuracy(y_test, y_pred))

# Calculate the average accuracy across all folds
average_accuracy = sum(accuracy_scores) / len(accuracy_scores)
avg_precision = sum(precision_scores) / len(precision_scores)
avg_acc_norm = sum(acc_norm)/len(acc_norm)
avg_recall = sum(recall_scores) / len(recall_scores)
avg_acc = sum(acc_scores)/len(acc_scores)
f1 = 2 * (avg_precision * avg_recall) / (avg_precision + avg_recall)
grand_mean=(average_accuracy+avg_precision+avg_recall+f1+avg_acc_norm++avg_acc)/6
# Print the average accuracy
print("Average Accuracy: ", average_accuracy)
print("Accuracy: ", avg_acc)
print("Average Normalized Accuracy: ", avg_acc_norm)
print("Average Precision: ", avg_precision)
print("Average Recall: ", avg_recall)
print('F1 score:', f1)
print('Grand Mean:', grand_mean)
# Out:
# Epoch 1/15
# 48/48 [==============================] - 1s 8ms/step - loss: 0.5241 - accuracy: 0.3646 - val_loss: 0.5309 - val_accuracy: 0.2000 - lr: 0.0010
# Epoch 2/15
# 48/48 [==============================] - 0s 6ms/step - loss: 0.3926 - accuracy: 0.5521 - val_loss: 0.4017 - val_accuracy: 0.5600 - lr: 0.0010
# Epoch 3/15
# 48/48 [==============================] - 0s 5ms/step - loss: 0.3033 - accuracy: 0.6771 - val_loss: 0.5170 - val_accuracy: 0.3200 - lr: 0.0010
# Epoch 4/15
# 48/48 [==============================] - 0s 5ms/step - loss: 0.2979 - accuracy: 0.7083 - val_loss: 0.4218 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 5/15
# 48/48 [==============================] - 0s 6ms/step - loss: 0.2404 - accuracy: 0.8021 - val_loss: 0.5401 - val_accuracy: 0.2800 - lr: 0.0010
# Epoch 6/15
# 48/48 [==============================] - 0s 5ms/step - loss: 0.2433 - accuracy: 0.7292 - val_loss: 0.4985 - val_accuracy: 0.3200 - lr: 0.0010
# Epoch 7/15
# 38/48 [======================>.......] - ETA: 0s - loss: 0.1861 - accuracy: 0.7895
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 48/48 [==============================] - 0s 5ms/step - loss: 0.2031 - accuracy: 0.7396 - val_loss: 0.4039 - val_accuracy: 0.5200 - lr: 0.0010
# Epoch 8/15
# 48/48 [==============================] - 0s 6ms/step - loss: 0.1870 - accuracy: 0.7604 - val_loss: 0.4395 - val_accuracy: 0.5200 - lr: 5.0000e-04
# Epoch 9/15
# 40/48 [========================>.....] - ETA: 0s - loss: 0.1478 - accuracy: 0.8750Restoring model weights from the end of the best epoch: 4.
# 48/48 [==============================] - 0s 5ms/step - loss: 0.1628 - accuracy: 0.8438 - val_loss: 0.4894 - val_accuracy: 0.4400 - lr: 5.0000e-04
# Epoch 9: early stopping
# 1/1 [==============================] - 0s 65ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 1s 8ms/step - loss: 0.3300 - accuracy: 0.6392 - val_loss: 0.2580 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.2763 - accuracy: 0.6804 - val_loss: 0.2478 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.2190 - accuracy: 0.7423 - val_loss: 0.2471 - val_accuracy: 0.7083 - lr: 0.0010
# Epoch 4/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.2168 - accuracy: 0.7629 - val_loss: 0.3094 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 5/15
# 40/49 [=======================>......] - ETA: 0s - loss: 0.1942 - accuracy: 0.7875
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.2072 - accuracy: 0.7732 - val_loss: 0.2667 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 6/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1609 - accuracy: 0.7835 - val_loss: 0.2367 - val_accuracy: 0.7917 - lr: 5.0000e-04
# Epoch 7/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1524 - accuracy: 0.8041 - val_loss: 0.2505 - val_accuracy: 0.7500 - lr: 5.0000e-04
# Epoch 8/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1336 - accuracy: 0.8660 - val_loss: 0.2512 - val_accuracy: 0.7083 - lr: 5.0000e-04
# Epoch 9/15
# 47/49 [===========================>..] - ETA: 0s - loss: 0.1333 - accuracy: 0.8511
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 49/49 [==============================] - 0s 7ms/step - loss: 0.1330 - accuracy: 0.8557 - val_loss: 0.2897 - val_accuracy: 0.6250 - lr: 5.0000e-04
# Epoch 10/15
# 49/49 [==============================] - 0s 9ms/step - loss: 0.1227 - accuracy: 0.8557 - val_loss: 0.2783 - val_accuracy: 0.7500 - lr: 2.5000e-04
# Epoch 11/15
# 45/49 [==========================>...] - ETA: 0s - loss: 0.1106 - accuracy: 0.9222Restoring model weights from the end of the best epoch: 6.
# 49/49 [==============================] - 0s 10ms/step - loss: 0.1163 - accuracy: 0.9072 - val_loss: 0.2398 - val_accuracy: 0.7500 - lr: 2.5000e-04
# Epoch 11: early stopping
# 1/1 [==============================] - 0s 101ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 2s 14ms/step - loss: 0.2063 - accuracy: 0.7732 - val_loss: 0.2758 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 9ms/step - loss: 0.1871 - accuracy: 0.7938 - val_loss: 0.1981 - val_accuracy: 0.9167 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 8ms/step - loss: 0.1638 - accuracy: 0.8144 - val_loss: 0.1992 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 4/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1659 - accuracy: 0.8144 - val_loss: 0.2218 - val_accuracy: 0.9167 - lr: 0.0010
# Epoch 5/15
# 40/49 [=======================>......] - ETA: 0s - loss: 0.1390 - accuracy: 0.8625
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1291 - accuracy: 0.8763 - val_loss: 0.3123 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 6/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1201 - accuracy: 0.8660 - val_loss: 0.2762 - val_accuracy: 0.7500 - lr: 5.0000e-04
# Epoch 7/15
# 43/49 [=========================>....] - ETA: 0s - loss: 0.1096 - accuracy: 0.8721Restoring model weights from the end of the best epoch: 2.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1139 - accuracy: 0.8660 - val_loss: 0.2606 - val_accuracy: 0.7500 - lr: 5.0000e-04
# Epoch 7: early stopping
# 1/1 [==============================] - 0s 67ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 1s 8ms/step - loss: 0.2076 - accuracy: 0.7423 - val_loss: 0.1501 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1891 - accuracy: 0.8041 - val_loss: 0.1266 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1766 - accuracy: 0.8351 - val_loss: 0.1269 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 4/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1231 - accuracy: 0.8454 - val_loss: 0.1641 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 5/15
# 40/49 [=======================>......] - ETA: 0s - loss: 0.1402 - accuracy: 0.8750
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1448 - accuracy: 0.8660 - val_loss: 0.1646 - val_accuracy: 0.7917 - lr: 0.0010
# Epoch 6/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1234 - accuracy: 0.9072 - val_loss: 0.1239 - val_accuracy: 0.8750 - lr: 5.0000e-04
# Epoch 7/15
# 47/49 [===========================>..] - ETA: 0s - loss: 0.1017 - accuracy: 0.8830Restoring model weights from the end of the best epoch: 2.
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0999 - accuracy: 0.8866 - val_loss: 0.1286 - val_accuracy: 0.8750 - lr: 5.0000e-04
# Epoch 7: early stopping
# 1/1 [==============================] - 0s 67ms/step
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 49/49 [==============================] - 1s 8ms/step - loss: 0.1952 - accuracy: 0.8247 - val_loss: 0.0857 - val_accuracy: 0.9167 - lr: 0.0010
# Epoch 2/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1571 - accuracy: 0.7835 - val_loss: 0.1214 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 3/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1543 - accuracy: 0.8247 - val_loss: 0.1196 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 4/15
# 48/49 [============================>.] - ETA: 0s - loss: 0.1821 - accuracy: 0.8438
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1825 - accuracy: 0.8454 - val_loss: 0.1404 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 5/15
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1355 - accuracy: 0.8557 - val_loss: 0.0880 - val_accuracy: 0.8750 - lr: 5.0000e-04
# Epoch 6/15
# 49/49 [==============================] - ETA: 0s - loss: 0.1153 - accuracy: 0.8557Restoring model weights from the end of the best epoch: 1.
# 49/49 [==============================] - 0s 7ms/step - loss: 0.1153 - accuracy: 0.8557 - val_loss: 0.0786 - val_accuracy: 0.8750 - lr: 5.0000e-04
# Epoch 6: early stopping
# 1/1 [==============================] - 0s 99ms/step
# Average Accuracy:  0.7373333333333333
# Accuracy:  0.9196666666666667
# Average Normalized Accuracy:  0.7774444444444445
# Average Precision:  0.7711996262846466
# Average Recall:  0.7614505494505495
# F1 score: 0.7662940812815481
# Grand Mean: 0.7888981169101981
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
